# %% [markdown]
# # 15 - Comparativa de resultados
#
# Notebook para recopilar y comparar todos los experimentos. Se diferencia del resto porque no entrena modelos: sirve para construir la tabla final del informe y decidir que modelo merece submission.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
results = [
    {'notebook': '01_ffnn_baseline_profesor', 'familia': 'ffNN', 'normalizacion': 'no', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'Baseline profesor'},
    {'notebook': '02_ffnn_simple', 'familia': 'ffNN', 'normalizacion': 'no', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'Una capa oculta pequena'},
    {'notebook': '03_ffnn_normalizada', 'familia': 'ffNN', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'Efecto de normalizar'},
    {'notebook': '04_ffnn_regularizada', 'familia': 'ffNN', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'BatchNorm + Dropout + L2'},
    {'notebook': '05_ffnn_pesos_clase', 'familia': 'ffNN', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'si', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'Compensa desbalance'},
    {'notebook': '06_cnn_simple', 'familia': 'CNN propia', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'Primera CNN'},
    {'notebook': '07_cnn_regularizada', 'familia': 'CNN propia', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'CNN con regularizacion'},
    {'notebook': '08_cnn_data_augmentation', 'familia': 'CNN propia', 'normalizacion': '0-1', 'augmentation': 'si', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'CNN + aumentos'},
    {'notebook': '09_resnet_scratch', 'familia': 'Popular scratch', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'ResNet50 sin ImageNet'},
    {'notebook': '10_vgg16_scratch', 'familia': 'Popular scratch', 'normalizacion': '0-1', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'VGG16 sin ImageNet'},
    {'notebook': '11_resnet_transfer_learning', 'familia': 'Transfer learning', 'normalizacion': 'resnet50', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'ResNet50 ImageNet + fine-tuning'},
    {'notebook': '12_efficientnet_transfer_learning', 'familia': 'Transfer learning', 'normalizacion': 'efficientnet', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'EfficientNetB0 ImageNet + fine-tuning'},
    {'notebook': '13_densenet_transfer_learning', 'familia': 'Transfer learning', 'normalizacion': 'densenet', 'augmentation': 'no', 'class_weight': 'no', 'val_accuracy': None, 'macro_f1': None, 'comentario': 'DenseNet121 ImageNet + fine-tuning'},
]

df_results = pd.DataFrame(results)
df_results

# %%
filled = df_results.dropna(subset=['val_accuracy']).sort_values('val_accuracy', ascending=False)
filled

# %%
if not filled.empty:
    plt.figure(figsize=(12, 5))
    plt.bar(filled['notebook'], filled['val_accuracy'])
    plt.xticks(rotation=45, ha='right')
    plt.ylabel('Validation accuracy')
    plt.title('Comparativa de modelos')
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Criterios de comparacion
#
# La comparativa se centra en `val_accuracy`, `macro_f1`, el comportamiento en clases minoritarias y el coste de entrenamiento de cada modelo.
