# %% [markdown]
# # 06_1 - CNN simple cargando todo en RAM
#
# CNN simple que lee las etiquetas desde JSON, hace split estratificado y carga train/valid una sola vez en RAM. Sirve para medir el coste de preparar arrays desde `.tif` frente al entrenamiento posterior.

# %% [markdown]
# ## Librerias y configuracion

# %%
import json
import time
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

RUN_START = time.perf_counter()

print('GPUs disponibles:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-05-29 09:15:26.769488: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780046126.979356      57 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780046127.043587      57 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780046127.571372      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780046127.571420      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780046127.571423      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780046127.571425      57 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
KAGGLE_INPUT_DIR = Path('/kaggle/input')
if not KAGGLE_INPUT_DIR.exists():
    raise FileNotFoundError('No existe /kaggle/input. Ejecuta este notebook en Kaggle.')

json_matches = sorted(KAGGLE_INPUT_DIR.rglob('xview_ann_train.json'))
if not json_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(f'No se encontro xview_ann_train.json. Inputs disponibles: {available_inputs}')

ANN_JSON = json_matches[0]
DATA_ROOT = ANN_JSON.parent
TRAIN_DIR = DATA_ROOT / 'xview_train'
TEST_DIR = DATA_ROOT / 'xview_test'
WORKDIR = Path('/kaggle/working')

print('DATA_ROOT:', DATA_ROOT)
print('ANN_JSON:', ANN_JSON)
print('TRAIN_DIR exists:', TRAIN_DIR.exists())
print('TEST_DIR exists:', TEST_DIR.exists())
# Out:
# DATA_ROOT: /kaggle/input/datasets/eccvdl/xview-recognition
# ANN_JSON: /kaggle/input/datasets/eccvdl/xview-recognition/xview_ann_train.json
# TRAIN_DIR exists: True
# TEST_DIR exists: True

# %% [markdown]
# ## Datos

# %% [markdown]
# ### Lectura del JSON

# %%
with open(ANN_JSON, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

categories = {
    int(k): v['name']
    for k, v in sorted(json_data['categories'].items(), key=lambda item: int(item[0]))
}
category_names = list(categories.values())
category_to_idx = {name: idx for idx, name in categories.items()}
num_classes = len(category_names)

rows = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    rows.append({
        'image_id': json_img['image_id'],
        'filename': json_img['filename'],
        'width': json_img['width'],
        'height': json_img['height'],
        'category': json_ann['category_id'],
        'label': category_to_idx[json_ann['category_id']],
        'bbox': json_ann['bbox'],
        'exists': (DATA_ROOT / json_img['filename']).exists(),
    })

df = pd.DataFrame(rows)
print('Categorias:')
print(categories)
print('Total train:', len(df))
print('Archivos encontrados:', int(df['exists'].sum()))
df.head()
# Out:
# Categorias:
# {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}
# Total train: 18746
# Archivos encontrados: 18746
#                                    image_id  \
# 0  0234476c-a017-4c9b-bd2f-872193076cca.tif
# 1  f2543073-9933-44c4-98e0-15eee2dffe2a.tif
# 2  6df5b6a5-82b0-4abb-8deb-7d7154c977bc.tif
# 3  ddbd2636-ce3c-4406-a5cf-92fa557dbd3c.tif
# 4  609064d1-3719-4163-ad36-577dab9805f0.tif
#
#                                             filename  width  height  category  \
# 0  xview_train/Building/0234476c-a017-4c9b-bd2f-8...    224     224  Building
# 1  xview_train/Building/f2543073-9933-44c4-98e0-1...    224     224  Building
# 2  xview_train/Building/6df5b6a5-82b0-4abb-8deb-7...    224     224  Building
# 3  xview_train/Building/ddbd2636-ce3c-4406-a5cf-9...    224     224  Building
# 4  xview_train/Building/609064d1-3719-4163-ad36-5...    224     224  Building
#
#    label              bbox  exists
# 0      8  [0, 0, 224, 224]    True
# 1      8  [0, 0, 224, 224]    True
# 2      8  [0, 0, 224, 224]    True
# 3      8  [0, 0, 224, 224]    True
# 4      8  [0, 0, 224, 224]    True

# %%
class_counts = df['category'].value_counts().reindex(category_names)
print('Distribucion por clase:')
print(class_counts)

plt.figure(figsize=(12, 5))
plt.bar(class_counts.index, class_counts.values)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Numero de imagenes')
plt.title('Distribucion de clases')
plt.tight_layout()
plt.show()
# Out:
# Distribucion por clase:
# category
# Cargo plane            635
# Small car             3324
# Bus                   1768
# Truck                 2210
# Motorboat             1069
# Fishing vessel         706
# Dump truck            1236
# Excavator              789
# Building              3594
# Helipad                111
# Storage tank          1469
# Shipping container    1523
# Pylon                  312
# Name: count, dtype: int64

# %% [markdown]
# ### Comprobacion de una imagen

# %%
def load_image(filename):
    return np.array(Image.open(DATA_ROOT / filename).convert('RGB'))

# %%
sample_row = df.iloc[0]
sample_img = load_image(sample_row['filename'])

print('Filename:', sample_row['filename'])
print('Shape:', sample_img.shape)
print('Dtype:', sample_img.dtype)
print('Min / Max:', sample_img.min(), sample_img.max())
print('Etiqueta:', sample_row['category'])
print('Indice de clase:', sample_row['label'])
print('Bounding box:', sample_row['bbox'])
print('Primeros pixeles del array:')
print(sample_img[:3, :3, :])

plt.figure(figsize=(4, 4))
plt.imshow(sample_img)
plt.title(sample_row['category'])
plt.axis('off')
plt.show()
# Out:
# Filename: xview_train/Building/0234476c-a017-4c9b-bd2f-872193076cca.tif
# Shape: (224, 224, 3)
# Dtype: uint8
# Min / Max: 0 86
# Etiqueta: Building
# Indice de clase: 8
# Bounding box: [0, 0, 224, 224]
# Primeros pixeles del array:
# [[[45 30 19]
#   [45 30 19]
#   [46 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]]

# %% [markdown]
# ### Split train/valid

# %%
train_df, val_df = train_test_split(
    df,
    test_size=0.15,
    random_state=42,
    shuffle=True,
    stratify=df['label'],
)

print('Train:', len(train_df))
print('Validation:', len(val_df))

split_counts = pd.concat([
    train_df['category'].value_counts().reindex(category_names).rename('train'),
    val_df['category'].value_counts().reindex(category_names).rename('valid'),
], axis=1)
split_counts
# Out:
# Train: 15934
# Validation: 2812
#                     train  valid
# category
# Cargo plane           540     95
# Small car            2825    499
# Bus                  1503    265
# Truck                1878    332
# Motorboat             909    160
# Fishing vessel        600    106
# Dump truck           1051    185
# Excavator             671    118
# Building             3055    539
# Helipad                94     17
# Storage tank         1249    220
# Shipping container   1294    229
# Pylon                 265     47

# %% [markdown]
# ### Carga en memoria RAM

# %%
DATA_LOAD_START = time.perf_counter()

def dataframe_to_arrays(data):
    n = len(data)
    X = np.empty((n, 224, 224, 3), dtype=np.uint8)
    y_idx = np.empty((n,), dtype=np.int32)

    for i, row in enumerate(data.itertuples(index=False)):
        X[i] = load_image(row.filename)
        y_idx[i] = row.label
        if (i + 1) % 1000 == 0:
            print(f'Cargadas {i + 1}/{n} imagenes')

    y = tf.keras.utils.to_categorical(y_idx, num_classes=num_classes).astype(np.float32)
    return X, y, y_idx

X_train, y_train, y_train_idx = dataframe_to_arrays(train_df)
X_valid, y_valid, y_valid_idx = dataframe_to_arrays(val_df)

DATA_LOAD_TIME = time.perf_counter() - DATA_LOAD_START

print('X_train:', X_train.shape, X_train.dtype, 'RAM aprox:', X_train.nbytes / 1024**3, 'GB')
print('X_valid:', X_valid.shape, X_valid.dtype, 'RAM aprox:', X_valid.nbytes / 1024**3, 'GB')
print('y_train:', y_train.shape, y_train.dtype)
print('y_valid:', y_valid.shape, y_valid.dtype)
print(f'Tiempo carga datos: {DATA_LOAD_TIME:.2f} s')
# Out:
# Cargadas 1000/15934 imagenes
# Cargadas 2000/15934 imagenes
# Cargadas 3000/15934 imagenes
# Cargadas 4000/15934 imagenes
# Cargadas 5000/15934 imagenes
# Cargadas 6000/15934 imagenes
# Cargadas 7000/15934 imagenes
# Cargadas 8000/15934 imagenes
# Cargadas 9000/15934 imagenes
# Cargadas 10000/15934 imagenes
# Cargadas 11000/15934 imagenes
# Cargadas 12000/15934 imagenes
# Cargadas 13000/15934 imagenes
# Cargadas 14000/15934 imagenes
# Cargadas 15000/15934 imagenes
# Cargadas 1000/2812 imagenes
# Cargadas 2000/2812 imagenes
# X_train: (15934, 224, 224, 3) uint8 RAM aprox: 2.2337894439697266 GB
# X_valid: (2812, 224, 224, 3) uint8 RAM aprox: 0.3942146301269531 GB
# y_train: (15934, 13) float32
# y_valid: (2812, 13) float32
# Tiempo carga datos: 171.93 s

# %% [markdown]
# ## Red

# %% [markdown]
# ### Arquitectura y summary

# %%
BATCH_SIZE = 32
EPOCHS = 40

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224, 224, 3)),
    tf.keras.layers.Rescaling(1.0 / 255.0),
    tf.keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.Conv2D(128, 3, padding='same', activation='relu'),
    tf.keras.layers.MaxPooling2D(),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax'),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model.summary()
# Out:
# I0000 00:00:1780046358.375241      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780046358.381285      57 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 111,437 (435.30 KB)
#  Trainable params: 111,437 (435.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Callbacks

# %%
MODEL_PATH = WORKDIR / '06_1_cnn_simple_ram.keras'
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(str(MODEL_PATH), monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=8, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-7, verbose=1),
    tf.keras.callbacks.TerminateOnNaN(),
]

print('Modelo guardado en:', MODEL_PATH)
# Out:
# Modelo guardado en: /kaggle/working/06_1_cnn_simple_ram.keras

# %% [markdown]
# ### Entrenamiento

# %%
TRAIN_START = time.perf_counter()

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks,
    verbose=1,
)

TRAIN_TIME = time.perf_counter() - TRAIN_START

best_idx = int(np.argmax(history.history['val_accuracy']))
best_value = float(np.max(history.history['val_accuracy']))
print('Best validation model: epoch', best_idx + 1, '- val_accuracy', best_value)
print(f'Tiempo entrenamiento: {TRAIN_TIME:.2f} s')
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780046366.808325     135 service.cc:152] XLA service 0x7b5e1004a590 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780046366.808375     135 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780046366.808381     135 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780046367.186078     135 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   3/498 ━━━━━━━━━━━━━━━━━━━━ 22s 45ms/step - accuracy: 0.1510 - loss: 2.5639
# I0000 00:00:1780046371.918706     135 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.2156 - loss: 2.2823
# Epoch 1: val_accuracy improved from None to 0.29765, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 1: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 38s 62ms/step - accuracy: 0.2445 - loss: 2.1683 - val_accuracy: 0.2977 - val_loss: 1.9785 - learning_rate: 0.0010
# Epoch 2/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3332 - loss: 1.8989
# Epoch 2: val_accuracy improved from 0.29765 to 0.36878, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 2: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 24s 48ms/step - accuracy: 0.3511 - loss: 1.8420 - val_accuracy: 0.3688 - val_loss: 1.7761 - learning_rate: 0.0010
# Epoch 3/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3974 - loss: 1.7182
# Epoch 3: val_accuracy improved from 0.36878 to 0.46942, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 3: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 24s 49ms/step - accuracy: 0.4172 - loss: 1.6724 - val_accuracy: 0.4694 - val_loss: 1.5876 - learning_rate: 0.0010
# Epoch 4/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4519 - loss: 1.5871
# Epoch 4: val_accuracy improved from 0.46942 to 0.47760, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 4: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 25s 49ms/step - accuracy: 0.4618 - loss: 1.5587 - val_accuracy: 0.4776 - val_loss: 1.5323 - learning_rate: 0.0010
# Epoch 5/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4839 - loss: 1.4954
# Epoch 5: val_accuracy improved from 0.47760 to 0.49893, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 5: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 25s 50ms/step - accuracy: 0.4893 - loss: 1.4818 - val_accuracy: 0.4989 - val_loss: 1.4552 - learning_rate: 0.0010
# Epoch 6/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5002 - loss: 1.4270
# Epoch 6: val_accuracy did not improve from 0.49893
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.5063 - loss: 1.4244 - val_accuracy: 0.4886 - val_loss: 1.4584 - learning_rate: 0.0010
# Epoch 7/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5185 - loss: 1.3988
# Epoch 7: val_accuracy improved from 0.49893 to 0.52134, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 7: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 25s 51ms/step - accuracy: 0.5196 - loss: 1.3891 - val_accuracy: 0.5213 - val_loss: 1.3972 - learning_rate: 0.0010
# Epoch 8/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5327 - loss: 1.3553
# Epoch 8: val_accuracy improved from 0.52134 to 0.54018, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 8: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 51ms/step - accuracy: 0.5338 - loss: 1.3524 - val_accuracy: 0.5402 - val_loss: 1.3942 - learning_rate: 0.0010
# Epoch 9/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.5452 - loss: 1.3033
# Epoch 9: val_accuracy improved from 0.54018 to 0.54801, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 9: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step - accuracy: 0.5439 - loss: 1.3210 - val_accuracy: 0.5480 - val_loss: 1.3051 - learning_rate: 0.0010
# Epoch 10/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5456 - loss: 1.3133
# Epoch 10: val_accuracy improved from 0.54801 to 0.55654, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 10: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step - accuracy: 0.5514 - loss: 1.2973 - val_accuracy: 0.5565 - val_loss: 1.3117 - learning_rate: 0.0010
# Epoch 11/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5631 - loss: 1.2486
# Epoch 11: val_accuracy improved from 0.55654 to 0.56579, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 11: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step - accuracy: 0.5582 - loss: 1.2695 - val_accuracy: 0.5658 - val_loss: 1.2823 - learning_rate: 0.0010
# Epoch 12/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5741 - loss: 1.2297
# Epoch 12: val_accuracy improved from 0.56579 to 0.57112, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 12: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step - accuracy: 0.5685 - loss: 1.2424 - val_accuracy: 0.5711 - val_loss: 1.2867 - learning_rate: 0.0010
# Epoch 13/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5733 - loss: 1.2353
# Epoch 13: val_accuracy did not improve from 0.57112
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 52ms/step - accuracy: 0.5733 - loss: 1.2304 - val_accuracy: 0.5498 - val_loss: 1.3134 - learning_rate: 0.0010
# Epoch 14/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5810 - loss: 1.2032
# Epoch 14: val_accuracy improved from 0.57112 to 0.57290, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 14: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.5832 - loss: 1.2032 - val_accuracy: 0.5729 - val_loss: 1.2364 - learning_rate: 0.0010
# Epoch 15/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5979 - loss: 1.1661
# Epoch 15: val_accuracy improved from 0.57290 to 0.57824, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 15: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.5938 - loss: 1.1839 - val_accuracy: 0.5782 - val_loss: 1.2196 - learning_rate: 0.0010
# Epoch 16/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5974 - loss: 1.1727
# Epoch 16: val_accuracy improved from 0.57824 to 0.58073, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 16: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.5957 - loss: 1.1643 - val_accuracy: 0.5807 - val_loss: 1.2017 - learning_rate: 0.0010
# Epoch 17/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5993 - loss: 1.1497
# Epoch 17: val_accuracy did not improve from 0.58073
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6015 - loss: 1.1479 - val_accuracy: 0.5765 - val_loss: 1.2245 - learning_rate: 0.0010
# Epoch 18/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6005 - loss: 1.1508
# Epoch 18: val_accuracy did not improve from 0.58073
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6074 - loss: 1.1380 - val_accuracy: 0.5558 - val_loss: 1.2784 - learning_rate: 0.0010
# Epoch 19/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5971 - loss: 1.1538
# Epoch 19: val_accuracy did not improve from 0.58073
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6060 - loss: 1.1283 - val_accuracy: 0.5786 - val_loss: 1.2257 - learning_rate: 0.0010
# Epoch 20/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6262 - loss: 1.0721
# Epoch 20: val_accuracy improved from 0.58073 to 0.62198, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 20: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6340 - loss: 1.0504 - val_accuracy: 0.6220 - val_loss: 1.1152 - learning_rate: 3.0000e-04
# Epoch 21/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6420 - loss: 1.0306
# Epoch 21: val_accuracy improved from 0.62198 to 0.62660, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 21: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6400 - loss: 1.0360 - val_accuracy: 0.6266 - val_loss: 1.1163 - learning_rate: 3.0000e-04
# Epoch 22/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6353 - loss: 1.0473
# Epoch 22: val_accuracy did not improve from 0.62660
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6412 - loss: 1.0292 - val_accuracy: 0.6202 - val_loss: 1.1096 - learning_rate: 3.0000e-04
# Epoch 23/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6398 - loss: 1.0341
# Epoch 23: val_accuracy improved from 0.62660 to 0.62909, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 23: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6433 - loss: 1.0198 - val_accuracy: 0.6291 - val_loss: 1.0998 - learning_rate: 3.0000e-04
# Epoch 24/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6508 - loss: 1.0004
# Epoch 24: val_accuracy did not improve from 0.62909
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6465 - loss: 1.0147 - val_accuracy: 0.6248 - val_loss: 1.0993 - learning_rate: 3.0000e-04
# Epoch 25/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6470 - loss: 1.0019
# Epoch 25: val_accuracy did not improve from 0.62909
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6467 - loss: 1.0116 - val_accuracy: 0.6255 - val_loss: 1.0984 - learning_rate: 3.0000e-04
# Epoch 26/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6537 - loss: 1.0018
# Epoch 26: val_accuracy did not improve from 0.62909
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6481 - loss: 1.0051 - val_accuracy: 0.6262 - val_loss: 1.1048 - learning_rate: 3.0000e-04
# Epoch 27/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6516 - loss: 0.9923
# Epoch 27: val_accuracy improved from 0.62909 to 0.62945, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 27: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6509 - loss: 0.9999 - val_accuracy: 0.6294 - val_loss: 1.0866 - learning_rate: 3.0000e-04
# Epoch 28/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6527 - loss: 0.9918
# Epoch 28: val_accuracy did not improve from 0.62945
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6536 - loss: 0.9927 - val_accuracy: 0.6248 - val_loss: 1.1020 - learning_rate: 3.0000e-04
# Epoch 29/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6580 - loss: 0.9817
# Epoch 29: val_accuracy did not improve from 0.62945
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6537 - loss: 0.9940 - val_accuracy: 0.6280 - val_loss: 1.0817 - learning_rate: 3.0000e-04
# Epoch 30/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6520 - loss: 0.9943
# Epoch 30: val_accuracy improved from 0.62945 to 0.63656, saving model to /kaggle/working/06_1_cnn_simple_ram.keras
#
# Epoch 30: finished saving model to /kaggle/working/06_1_cnn_simple_ram.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6560 - loss: 0.9866 - val_accuracy: 0.6366 - val_loss: 1.0966 - learning_rate: 3.0000e-04
# Epoch 31/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6572 - loss: 0.9843
# Epoch 31: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6557 - loss: 0.9828 - val_accuracy: 0.6294 - val_loss: 1.0775 - learning_rate: 3.0000e-04
# Epoch 32/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6581 - loss: 0.9550
# Epoch 32: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6562 - loss: 0.9801 - val_accuracy: 0.6284 - val_loss: 1.0809 - learning_rate: 3.0000e-04
# Epoch 33/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6619 - loss: 0.9615
# Epoch 33: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6593 - loss: 0.9724 - val_accuracy: 0.6227 - val_loss: 1.0969 - learning_rate: 3.0000e-04
# Epoch 34/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6557 - loss: 0.9805
# Epoch 34: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6607 - loss: 0.9712 - val_accuracy: 0.6337 - val_loss: 1.0753 - learning_rate: 3.0000e-04
# Epoch 35/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6581 - loss: 0.9709
# Epoch 35: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6615 - loss: 0.9660 - val_accuracy: 0.6348 - val_loss: 1.0726 - learning_rate: 3.0000e-04
# Epoch 36/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6672 - loss: 0.9599
# Epoch 36: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6630 - loss: 0.9634 - val_accuracy: 0.6358 - val_loss: 1.0751 - learning_rate: 3.0000e-04
# Epoch 37/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6623 - loss: 0.9485
# Epoch 37: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6635 - loss: 0.9575 - val_accuracy: 0.6255 - val_loss: 1.0881 - learning_rate: 3.0000e-04
# Epoch 38/40
# 497/498 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.6703 - loss: 0.9353
# Epoch 38: val_accuracy did not improve from 0.63656
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 26s 53ms/step - accuracy: 0.6658 - loss: 0.9530 - val_accuracy: 0.6330 - val_loss: 1.0662 - learning_rate: 3.0000e-04
# Epoch 38: early stopping
# Restoring model weights from the end of the best epoch: 30.
# Best validation model: epoch 30 - val_accuracy 0.6365576386451721
# Tiempo entrenamiento: 1005.02 s

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### Graficas de entrenamiento

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de confusion

# %%
model.load_weights(MODEL_PATH)
probs = model.predict(X_valid, batch_size=BATCH_SIZE, verbose=1)
y_pred_idx = np.argmax(probs, axis=1)
y_true_idx = y_valid_idx

cm = confusion_matrix(y_true_idx, y_pred_idx, labels=list(range(num_classes)))
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step

# %%
def draw_confusion_matrix_percent(cm, labels):
    cm_norm = cm.astype(float) / np.maximum(cm.sum(axis=1, keepdims=True), np.finfo(np.float64).eps)

    fig, ax = plt.subplots(figsize=(14, 12))
    im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.colormaps['Blues'], vmin=0.0, vmax=max(0.01, cm_norm.max()))
    fig.colorbar(im, ax=ax)

    ax.set(
        xticks=np.arange(len(labels)),
        yticks=np.arange(len(labels)),
        xticklabels=labels,
        yticklabels=labels,
        ylabel='Annotation',
        xlabel='Prediction',
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

    threshold = cm_norm.max() / 2.0
    for i in range(cm_norm.shape[0]):
        for j in range(cm_norm.shape[1]):
            value = cm_norm[i, j]
            ax.text(j, i, f'{value:.2f}', ha='center', va='center', color='white' if value > threshold else 'black', fontsize=9)

    ax.set_title('Matriz de confusion normalizada por clase real')
    fig.tight_layout()
    plt.show()

draw_confusion_matrix_percent(cm, category_names)

# %% [markdown]
# ### Metricas por clase

# %%
correct = np.diag(cm).astype(float)
total_true = np.sum(cm, axis=1).astype(float)
total_pred = np.sum(cm, axis=0).astype(float)

print('Mean Accuracy: %.3f%%' % (np.sum(correct) / np.sum(total_true) * 100))
print('Mean Recall: %.3f%%' % ((correct / np.maximum(total_true, np.finfo(np.float64).eps)).mean() * 100))
print('Mean Precision: %.3f%%' % ((correct / np.maximum(total_pred, np.finfo(np.float64).eps)).mean() * 100))

for idx, name in enumerate(category_names):
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    recall = tp / np.maximum(tp + fn, np.finfo(np.float64).eps)
    precision = tp / np.maximum(tp + fp, np.finfo(np.float64).eps)
    specificity = tn / np.maximum(tn + fp, np.finfo(np.float64).eps)
    f1_score = 2 * ((precision * recall) / np.maximum(precision + recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (name, recall * 100, precision * 100, specificity * 100, f1_score * 100))
# Out:
# Mean Accuracy: 63.656%
# Mean Recall: 59.809%
# Mean Precision: 64.048%
# > Cargo plane: Recall: 87.368% Precision: 92.222% Specificity: 99.742% Dice: 89.730%
# > Small car: Recall: 92.385% Precision: 64.028% Specificity: 88.802% Dice: 75.636%
# > Bus: Recall: 42.264% Precision: 53.081% Specificity: 96.113% Dice: 47.059%
# > Truck: Recall: 23.193% Precision: 36.493% Specificity: 94.597% Dice: 28.361%
# > Motorboat: Recall: 63.750% Precision: 71.329% Specificity: 98.454% Dice: 67.327%
# > Fishing vessel: Recall: 69.811% Precision: 73.267% Specificity: 99.002% Dice: 71.498%
# > Dump truck: Recall: 47.027% Precision: 59.589% Specificity: 97.754% Dice: 52.568%
# > Excavator: Recall: 68.644% Precision: 56.643% Specificity: 97.699% Dice: 62.069%
# > Building: Recall: 79.035% Precision: 72.572% Specificity: 92.917% Dice: 75.666%
# > Helipad: Recall: 17.647% Precision: 50.000% Specificity: 99.893% Dice: 26.087%
# > Storage tank: Recall: 38.182% Precision: 64.615% Specificity: 98.225% Dice: 48.000%
# > Shipping container: Recall: 71.616% Precision: 58.781% Specificity: 95.548% Dice: 64.567%
# > Pylon: Recall: 76.596% Precision: 80.000% Specificity: 99.675% Dice: 78.261%

# %% [markdown]
# ## Codabench

# %%
CODABENCH_START = time.perf_counter()

def load_test_image(filename):
    return np.array(Image.open(DATA_ROOT / filename).convert('RGB'))

test_files = sorted(TEST_DIR.rglob('*.tif'))
print('Number of testing images:', len(test_files))
assert len(test_files) > 0, 'No se encontraron imagenes .tif en TEST_DIR.'

model.load_weights(MODEL_PATH)
predictions_data = {'images': {}, 'annotations': {}}
batch_size = 64

for start in range(0, len(test_files), batch_size):
    batch_paths = test_files[start:start + batch_size]
    json_filenames = [path.relative_to(TEST_DIR).as_posix() for path in batch_paths]
    load_filenames = [path.relative_to(DATA_ROOT).as_posix() for path in batch_paths]

    images = np.stack([load_test_image(filename) for filename in load_filenames]).astype(np.uint8)
    probs = model.predict(images, batch_size=batch_size, verbose=0)
    pred_idx = np.argmax(probs, axis=1)
    pred_scores = np.max(probs, axis=1)

    for offset, (path, json_filename, cls_idx, score) in enumerate(zip(batch_paths, json_filenames, pred_idx, pred_scores)):
        idx = start + offset
        predictions_data['images'][idx] = {
            'image_id': path.name,
            'filename': json_filename,
            'width': 224,
            'height': 224,
        }
        predictions_data['annotations'][idx] = {
            'image_id': path.name,
            'category_id': category_names[int(cls_idx)],
            'score': float(score),
            'bbox': [0, 0, 224, 224],
        }

    print(f'Procesadas {min(start + batch_size, len(test_files))}/{len(test_files)}')

assert len(predictions_data['images']) == len(test_files)
assert len(predictions_data['annotations']) == len(test_files)

prediction_path = WORKDIR / 'prediction_06_1.json'
submission_path = WORKDIR / 'submission_06_1.zip'

with open(prediction_path, 'w', encoding='utf-8') as outfile:
    json.dump(predictions_data, outfile)

with zipfile.ZipFile(submission_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    zf.write(prediction_path, arcname='prediction.json')

CODABENCH_TIME = time.perf_counter() - CODABENCH_START

print('Archivos generados:')
print(prediction_path, '-', prediction_path.stat().st_size, 'bytes')
print(submission_path, '-', submission_path.stat().st_size, 'bytes')
print(f'Tiempo Codabench: {CODABENCH_TIME:.2f} s')

from IPython.display import FileLink, display
display(FileLink(str(submission_path)))
# Out:
# Number of testing images: 2365
# Procesadas 64/2365
# Procesadas 128/2365
# Procesadas 192/2365
# Procesadas 256/2365
# Procesadas 320/2365
# Procesadas 384/2365
# Procesadas 448/2365
# Procesadas 512/2365
# Procesadas 576/2365
# Procesadas 640/2365
# Procesadas 704/2365
# Procesadas 768/2365
# Procesadas 832/2365
# Procesadas 896/2365
# Procesadas 960/2365
# Procesadas 1024/2365
# Procesadas 1088/2365
# Procesadas 1152/2365
# Procesadas 1216/2365
# Procesadas 1280/2365
# Procesadas 1344/2365
# Procesadas 1408/2365
# Procesadas 1472/2365
# Procesadas 1536/2365
# Procesadas 1600/2365
# Procesadas 1664/2365
# Procesadas 1728/2365
# Procesadas 1792/2365
# Procesadas 1856/2365
# Procesadas 1920/2365
# Procesadas 1984/2365
# Procesadas 2048/2365
# Procesadas 2112/2365
# Procesadas 2176/2365
# Procesadas 2240/2365
# Procesadas 2304/2365
# Procesadas 2365/2365
# Archivos generados:
# /kaggle/working/prediction_06_1.json - 730168 bytes
# /kaggle/working/submission_06_1.zip - 165171 bytes
# Tiempo Codabench: 34.14 s
# /kaggle/working/submission_06_1.zip

# %% [markdown]
# ## Tiempo total

# %%
TOTAL_TIME = time.perf_counter() - RUN_START
print('Resumen de tiempos')
if 'DATA_LOAD_TIME' in globals():
    print(f'- Carga/preparacion de datos: {DATA_LOAD_TIME:.2f} s')
if 'TRAIN_TIME' in globals():
    print(f'- Entrenamiento: {TRAIN_TIME:.2f} s')
if 'CODABENCH_TIME' in globals():
    print(f'- Codabench: {CODABENCH_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME / 60:.2f} min')
# Out:
# Resumen de tiempos
# - Carga/preparacion de datos: 171.93 s
# - Entrenamiento: 1005.02 s
# - Codabench: 34.14 s
# - Tiempo total Run All: 1262.05 s
# - Tiempo total Run All: 21.03 min
