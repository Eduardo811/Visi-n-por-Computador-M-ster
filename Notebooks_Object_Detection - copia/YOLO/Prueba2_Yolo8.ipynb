# %% [markdown]
# # Prueba 2 - Ajuste de YOLOv8 XS con KerasCV para xView Detection
#
# Este notebook desarrolla una segunda iteracion sobre la linea base YOLOv8 XS. Mantiene la familia de modelo y el flujo general de KerasCV, pero modifica parametros relevantes para escenas densas de xView: umbral de confianza mas bajo, NMS mas restrictivo, entrenamiento mas largo, reduccion adaptativa del learning rate y aumentos algo menos agresivos. La finalidad es comprobar si un ajuste fino del detector de una etapa mejora la recuperacion de objetos pequenos y clases minoritarias sin cambiar todavia de arquitectura.
#
# La estructura del cuaderno sigue el recorrido completo de la entrega: preparacion del entorno y del dataset, lectura de anotaciones, reparto de 6845 imagenes para entrenamiento y 761 para validacion, construccion del modelo YOLOv8 XS, generacion de datasets `tf.data`, entrenamiento con callbacks de guardado y evaluacion con metricas por clase. En la fase de validacion se calculan precision, recall, AP, matriz de confusion y mAP para poder comparar directamente con la primera prueba.
#
# El mejor modelo se guarda en la epoca 45 con `val_loss = 2.3738`. En validacion alcanza `mAP = 18.734%`, mejorando ligeramente la prueba inicial aunque todavia con rendimiento bajo en Bus y Truck. El notebook termina generando `prediction_v2.json` y el ZIP `submission_v2.zip`, que sirve como entrega de esta configuracion.

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import uuid
import numpy as np

class GenericObject:
    """
    Generic object data.
    """
    def __init__(self):
        self.id = uuid.uuid4()
        self.bb = (-1, -1, -1, -1)
        self.category= -1
        self.score = -1

class GenericImage:
    """
    Generic image data.
    """
    def __init__(self, filename):
        self.filename = filename
        self.tile = np.array([-1, -1, -1, -1])  # (pt_x, pt_y, pt_x+width, pt_y+height)
        self.objects = list([])

    def add_object(self, obj: GenericObject):
        self.objects.append(obj)

# %%
categories = {0: 'Small car', 1: 'Bus', 2: 'Truck', 3: 'Building'}

# %%
from pathlib import Path
import warnings
import rasterio
import numpy as np

LOCAL_DATA_ROOT = Path('../PROJECT/xview_detection')
KAGGLE_INPUT_DIR = Path('/kaggle/input')

json_candidates = []
if KAGGLE_INPUT_DIR.exists():
    json_candidates = sorted(KAGGLE_INPUT_DIR.rglob('xview_det_train.json'))
    if not json_candidates:
        json_candidates = sorted(KAGGLE_INPUT_DIR.rglob('xview_ann_train.json'))

if json_candidates:
    JSON_FILE = json_candidates[0]
    DATA_ROOT = JSON_FILE.parent
else:
    DATA_ROOT = LOCAL_DATA_ROOT
    JSON_FILE = DATA_ROOT / 'xview_det_train.json'

TRAIN_DIR = DATA_ROOT / 'xview_train'
TEST_DIR = DATA_ROOT / 'xview_test'
WORKDIR = Path('/kaggle/working') if Path('/kaggle/working').exists() else Path('.')

print('DATA_ROOT:', DATA_ROOT)
print('JSON_FILE:', JSON_FILE)
print('TRAIN_DIR exists:', TRAIN_DIR.exists())
print('TEST_DIR exists:', TEST_DIR.exists())


def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=rasterio.errors.NotGeoreferencedWarning)
    filepath = DATA_ROOT / filename
    if not filepath.exists():
        raise FileNotFoundError(f'No se encontro la imagen: {filepath}')

    src_raster = rasterio.open(filepath, 'r')
    # RasterIO to OpenCV (see inconsistencies between libjpeg and libjpeg-turbo)
    input_type = src_raster.profile['dtype']
    input_channels = src_raster.count
    img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=input_type)
    for band in range(input_channels):
        img[:, :, band] = src_raster.read(band+1)
    src_raster.close()
    return img
# Out:
# DATA_ROOT: /kaggle/input/datasets/victordmv/visu-detect
# JSON_FILE: /kaggle/input/datasets/victordmv/visu-detect/xview_det_train.json
# TRAIN_DIR exists: True
# TEST_DIR exists: True

# %% [markdown]
# #### Entrenamiento
#
# Se entrena la segunda configuracion de YOLOv8 XS con umbrales y callbacks ajustados para mejorar la linea base.

# %%
import json

# Load database
if not JSON_FILE.exists():
    raise FileNotFoundError(f'No se encontro el JSON de entrenamiento: {JSON_FILE}')

with open(JSON_FILE) as ifs:
    json_data = json.load(ifs)

# %%
import numpy as np

counts = dict.fromkeys(categories.values(), 0)
anns = []
for json_img in json_data['images'].values():
    image = GenericImage(json_img['filename'])
    image.tile = np.array([0, 0, json_img['width'], json_img['height']])
    for json_ann in [elem for elem in json_data['annotations'].values() if elem['image_id'] == json_img['image_id']]:
        obj = GenericObject()
        obj.id = json_ann['image_id']
        obj.bb = (int(json_ann['bbox'][0]), int(json_ann['bbox'][1]), int(json_ann['bbox'][2]), int(json_ann['bbox'][3]))
        obj.category = json_ann['category_id']
        counts[obj.category] += 1
        image.add_object(obj)
    anns.append(image)
print(counts)
# Out:
# {'Small car': 188300, 'Bus': 6269, 'Truck': 10600, 'Building': 275943}

# %%
from sklearn.model_selection import train_test_split

anns_train, anns_valid = train_test_split(anns, test_size=0.1, random_state=1, shuffle=True)
print('Number of training images: ' + str(len(anns_train)))
print('Number of validation images: ' + str(len(anns_valid)))
# Out:
# Number of training images: 6845
# Number of validation images: 761

# %%
# Load architecture
import keras_cv

# V2: umbrales de inferencia mÃ¡s permisivos para mejorar recall en objetos pequeÃ±os/densos.
YOLO_PRESET = 'yolo_v8_xs_backbone_coco'
YOLO_CONFIDENCE_THRESHOLD = 0.01
YOLO_NMS_IOU_THRESHOLD = 0.2

print('Load model')
print('Inference thresholds:', {'confidence': YOLO_CONFIDENCE_THRESHOLD, 'nms_iou': YOLO_NMS_IOU_THRESHOLD})
prediction_decoder = keras_cv.layers.NonMaxSuppression(
    bounding_box_format='xyxy',
    from_logits=False,
    confidence_threshold=YOLO_CONFIDENCE_THRESHOLD,
    iou_threshold=YOLO_NMS_IOU_THRESHOLD,
)
model = keras_cv.models.YOLOV8Detector.from_preset(
    preset=YOLO_PRESET,
    num_classes=len(categories),
    load_weights=True,
    bounding_box_format='xyxy',
    prediction_decoder=prediction_decoder,
)
model.summary()
# Out:
# Load model
# Inference thresholds: {'confidence': 0.01, 'nms_iou': 0.2}
# I0000 00:00:1780155626.401136      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780155626.407301      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "yolov8_detector"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, None,      │          0 │ -                 │
# │ (InputLayer)        │ None, 3)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ functional          │ [(None, None,     │  1,277,680 │ input_layer_1[0]… │
# │ (Functional)        │ None, 64), (None, │            │                   │
# │                     │ None, None, 128), │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 256)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat (Repeat)     │ (None, None,      │          0 │ functional[0][2]  │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_1 (Repeat)   │ (None, None,      │          0 │ repeat[0][0]      │
# │                     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, None,      │          0 │ repeat_1[0][0],   │
# │ (Concatenate)       │ None, 384)        │            │ functional[0][1]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_co… │ (None, None,      │     49,152 │ concatenate_5[0]… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_bn  │ (None, None,      │        512 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre     │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_4 (Split)     │ [(None, None,     │          0 │ pa_fpn_p4p5_pre[… │
# │                     │ None, 64), (None, │            │                   │
# │                     │ None, None, 64)]  │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ split_4[0][1]     │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │     36,864 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │        256 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │     36,864 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_… │ (None, None,      │        256 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_0_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │     36,864 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │        256 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_1 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │     36,864 │ pa_fpn_p4p5_pre_… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_… │ (None, None,      │        256 │ pa_fpn_p4p5_pre_… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_pre_1_2 │ (None, None,      │          0 │ pa_fpn_p4p5_pre_… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, None,      │          0 │ split_4[0][0],    │
# │ (Concatenate)       │ None, 256)        │            │ split_4[0][1],    │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# │                     │                   │            │ pa_fpn_p4p5_pre_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │     32,768 │ concatenate_6[0]… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output… │ (None, None,      │        512 │ pa_fpn_p4p5_outp… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p4p5_output  │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_2 (Repeat)   │ (None, None,      │          0 │ pa_fpn_p4p5_outp… │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ repeat_3 (Repeat)   │ (None, None,      │          0 │ repeat_2[0][0]    │
# │                     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, None,      │          0 │ repeat_3[0][0],   │
# │ (Concatenate)       │ None, 192)        │            │ functional[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │     12,288 │ concatenate_7[0]… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        256 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre   │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_5 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_pr… │
# │                     │ None, 32), (None, │            │                   │
# │                     │ None, None, 32)]  │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ split_5[0][1]     │
# │ (ZeroPadding2D)     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │      9,216 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        128 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │      9,216 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        128 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │      9,216 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        128 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (ZeroPadding2D)     │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │      9,216 │ pa_fpn_p3p4p5_pr… │
# │ (Conv2D)            │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │        128 │ pa_fpn_p3p4p5_pr… │
# │ (BatchNormalizatio… │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_pre_… │ (None, None,      │          0 │ pa_fpn_p3p4p5_pr… │
# │ (Activation)        │ None, 32)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_8       │ (None, None,      │          0 │ split_5[0][0],    │
# │ (Concatenate)       │ None, 128)        │            │ split_5[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# │                     │                   │            │ pa_fpn_p3p4p5_pr… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │      8,192 │ concatenate_8[0]… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │        256 │ pa_fpn_p3p4p5_ou… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_outp… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     36,864 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        256 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_9       │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 192)        │            │ pa_fpn_p4p5_outp… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     24,576 │ concatenate_9[0]… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_6 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 64), (None, │            │                   │
# │                     │ None, None, 64)]  │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_6[0][1]     │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     36,864 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        256 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     36,864 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        256 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     36,864 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        256 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     36,864 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        256 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_10      │ (None, None,      │          0 │ split_6[0][0],    │
# │ (Concatenate)       │ None, 256)        │            │ split_6[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     32,768 │ concatenate_10[0… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    147,456 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_11      │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Concatenate)       │ None, 384)        │            │ functional[0][2]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │     98,304 │ concatenate_11[0… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,024 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ split_7 (Split)     │ [(None, None,     │          0 │ pa_fpn_p3p4p5_do… │
# │                     │ None, 128),       │            │                   │
# │                     │ (None, None,      │            │                   │
# │                     │ None, 128)]       │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ split_7[0][1]     │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    147,456 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    147,456 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    147,456 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    147,456 │ pa_fpn_p3p4p5_do… │
# │ (Conv2D)            │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │        512 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_12      │ (None, None,      │          0 │ split_7[0][0],    │
# │ (Concatenate)       │ None, 512)        │            │ split_7[0][1],    │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# │                     │                   │            │ pa_fpn_p3p4p5_do… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │    131,072 │ concatenate_12[0… │
# │ (Conv2D)            │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │      1,024 │ pa_fpn_p3p4p5_do… │
# │ (BatchNormalizatio… │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pa_fpn_p3p4p5_down… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (Activation)        │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_ou… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │     36,864 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 128)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │     73,728 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ pa_fpn_p3p4p5_do… │
# │ (ZeroPadding2D)     │ None, 256)        │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │    147,456 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │     36,864 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        256 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │     73,728 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        256 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │    147,456 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        256 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        256 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        256 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        256 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │     36,864 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │     36,864 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (ZeroPadding2D)     │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │     36,864 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │     36,864 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        256 │ yolo_v8_head_1_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │     36,864 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        256 │ yolo_v8_head_2_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │     36,864 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        256 │ yolo_v8_head_3_c… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │        256 │ yolo_v8_head_1_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │        256 │ yolo_v8_head_2_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │        256 │ yolo_v8_head_3_b… │
# │ (BatchNormalizatio… │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │        260 │ yolo_v8_head_1_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │        260 │ yolo_v8_head_2_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Activation)        │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │        260 │ yolo_v8_head_3_c… │
# │ (Conv2D)            │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_box… │ (None, None,      │      4,160 │ yolo_v8_head_1_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_cla… │ (None, None,      │          0 │ yolo_v8_head_1_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_box… │ (None, None,      │      4,160 │ yolo_v8_head_2_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_cla… │ (None, None,      │          0 │ yolo_v8_head_2_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_box… │ (None, None,      │      4,160 │ yolo_v8_head_3_b… │
# │ (Conv2D)            │ None, 64)         │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_cla… │ (None, None,      │          0 │ yolo_v8_head_3_c… │
# │ (Activation)        │ None, 4)          │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_13      │ (None, None,      │          0 │ yolo_v8_head_1_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_1_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_14      │ (None, None,      │          0 │ yolo_v8_head_2_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_2_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_15      │ (None, None,      │          0 │ yolo_v8_head_3_b… │
# │ (Concatenate)       │ None, 68)         │            │ yolo_v8_head_3_c… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_1_out… │ (None, None, 68)  │          0 │ concatenate_13[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_2_out… │ (None, None, 68)  │          0 │ concatenate_14[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ yolo_v8_head_3_out… │ (None, None, 68)  │          0 │ concatenate_15[0… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_16      │ (None, None, 68)  │          0 │ yolo_v8_head_1_o… │
# │ (Concatenate)       │                   │            │ yolo_v8_head_2_o… │
# │                     │                   │            │ yolo_v8_head_3_o… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box_outputs         │ (None, None, 68)  │          0 │ concatenate_16[0… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item (GetItem)  │ (None, None, 64)  │          0 │ box_outputs[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ get_item_1          │ (None, None, 4)   │          0 │ box_outputs[0][0] │
# │ (GetItem)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ box (Concatenate)   │ (None, None, 64)  │          0 │ get_item[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ class (Concatenate) │ (None, None, 4)   │          0 │ get_item_1[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 3,536,316 (13.49 MB)
#  Trainable params: 3,524,764 (13.45 MB)
#  Non-trainable params: 11,552 (45.12 KB)

# %%
from tensorflow.keras.optimizers import SGD

# Learning rate is changed to 0.001
opt = SGD(learning_rate=1e-3, momentum=0.9, global_clipnorm=10.0)
model.compile(optimizer=opt, classification_loss='binary_crossentropy', box_loss='ciou', jit_compile=False)

# %%
from pathlib import Path
from tensorflow.keras.callbacks import CSVLogger, TerminateOnNaN, EarlyStopping, ReduceLROnPlateau, ModelCheckpoint

# V2 checkpoint. If available, warm-start from V2 first; otherwise continue from the V1 weights.
WORKDIR = Path('/kaggle/working') if Path('/kaggle/working').exists() else Path('.')
MODEL_PATH = WORKDIR / 'detector_v2_best.weights.h5'
PREVIOUS_MODEL_PATH = WORKDIR / 'detector_best.weights.h5'
TRAINING_LOG_PATH = WORKDIR / 'training_v2_log.csv'
RESUME_TRAINING = True


def get_available_weights_path(required=False):
    for candidate in [MODEL_PATH, PREVIOUS_MODEL_PATH]:
        if candidate.exists():
            return candidate
    if required:
        raise FileNotFoundError('No checkpoint found. Run the training cell first or add a previous detector_best.weights.h5 output.')
    return None

warm_start_path = get_available_weights_path() if RESUME_TRAINING else None
if warm_start_path is not None:
    print('Loading checkpoint from:', warm_start_path)
    model.load_weights(str(warm_start_path))
else:
    print('No previous checkpoint found. Training will start from the COCO-pretrained weights.')

# Callbacks
model_checkpoint = ModelCheckpoint(
    filepath=str(MODEL_PATH),
    monitor='val_loss',
    mode='min',
    verbose=1,
    save_best_only=True,
    save_weights_only=True,
)
csv_logger = CSVLogger(str(TRAINING_LOG_PATH), append=True)
reduce_lr = ReduceLROnPlateau('val_loss', factor=0.3, patience=5, min_lr=1e-6, verbose=1)
early_stop = EarlyStopping('val_loss', patience=15, verbose=1)
terminate = TerminateOnNaN()
callbacks = [model_checkpoint, csv_logger, reduce_lr, early_stop, terminate]

print('Best V2 model weights will be saved in:', MODEL_PATH)
print('Training log will be saved in:', TRAINING_LOG_PATH)
# Out:
# No previous checkpoint found. Training will start from the COCO-pretrained weights.
# Best V2 model weights will be saved in: /kaggle/working/detector_v2_best.weights.h5
# Training log will be saved in: /kaggle/working/training_v2_log.csv

# %%
# xView has very dense images; keep enough boxes per image without padding to an excessive value.
MAX_BOXES_PER_IMAGE = 1029


def image_generator(filename, tile, bboxes, categories):
    def load_sample(filepath):
        image = load_geoimage(filepath.numpy().decode('utf-8'))
        return tf.cast(image, tf.uint8)
    # Load image
    img = tf.squeeze(tf.py_function(func=load_sample, inp=[filename], Tout=[tf.uint8]), axis=0)  # tf.print(tf.shape(img)) -> [H, W, 3]
    img_roi = tf.image.pad_to_bounding_box(img, 0, 0, 640, 640)
    return {'images': tf.cast(img_roi, tf.float32), 'bounding_boxes': {'boxes': bboxes, 'classes': categories}}


def ragged_to_dense(inputs):
    from keras_cv import bounding_box
    return {
        'images': inputs['images'].to_tensor(),
        'bounding_boxes': bounding_box.to_dense(inputs['bounding_boxes'], max_boxes=MAX_BOXES_PER_IMAGE),
    }


def dict_to_tuple(inputs):
    return inputs['images'], inputs['bounding_boxes']

# %%
# Generate the list of objects from annotations
filenames_train, tiles_train, bboxes_train, categories_train = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_train)))
filenames_valid, tiles_valid, bboxes_valid, categories_valid = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns_valid)))
ds_train = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_train, tf.string), tf.cast(tiles_train, tf.int32), tf.cast(tf.ragged.constant(bboxes_train), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_train), tf.float32).to_tensor()))
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_train = ds_train.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE)
# Generators
batch_size = 4
shuffle_buffer = min(len(filenames_train), batch_size * 20)
ds_train = ds_train.shuffle(shuffle_buffer, reshuffle_each_iteration=True)
ds_train = ds_train.ragged_batch(batch_size=batch_size, drop_remainder=True)
ds_valid = ds_valid.ragged_batch(batch_size=batch_size, drop_remainder=True)
data_augmentation = tf.keras.Sequential(
    layers=[keras_cv.layers.RandomFlip(mode='horizontal_and_vertical', bounding_box_format='xyxy'),
            keras_cv.layers.RandomShear(x_factor=0.1, y_factor=0.1, bounding_box_format='xyxy'),
            keras_cv.layers.RandomColorDegeneration(factor=0.5)])
ds_train = ds_train.map(data_augmentation, num_parallel_calls=tf.data.AUTOTUNE)
# Bounding box tensors need to be Dense instead of Ragged
ds_train = ds_train.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_valid = ds_valid.map(ragged_to_dense, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
print('MAX_BOXES_PER_IMAGE:', MAX_BOXES_PER_IMAGE)
print('shuffle_buffer:', shuffle_buffer)
# Out:
# MAX_BOXES_PER_IMAGE: 1029
# shuffle_buffer: 80

# %%
import numpy as np

print('Training model - V2')
epochs = 60
train_steps, valid_steps = len(ds_train), len(ds_valid)
h = model.fit(ds_train, steps_per_epoch=train_steps, validation_data=ds_valid, validation_steps=valid_steps, epochs=epochs, callbacks=callbacks, verbose=1)
# Best validation model
best_idx = int(np.argmin(h.history['val_loss']))
best_value = np.min(h.history['val_loss'])
print('Best validation model: epoch ' + str(best_idx+1), ' - val_loss ' + str(best_value))
print('Best V2 weights:', MODEL_PATH)
# Out:
# Training model - V2
# Epoch 1/60
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780155707.399736     134 service.cc:152] XLA service 0x7bf9fd9c7930 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780155707.399790     134 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780155707.399797     134 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780155707.471974     134 cuda_dnn.cc:529] Loaded cuDNN version 91002
# I0000 00:00:1780155709.375851     134 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - box_loss: 3.2408 - class_loss: 10.5088 - loss: 13.7497
# Epoch 1: val_loss improved from None to 2.86981, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 1: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 614s 336ms/step - box_loss: 2.7208 - class_loss: 3.0398 - loss: 5.7607 - val_box_loss: 2.3672 - val_class_loss: 0.5026 - val_loss: 2.8698 - learning_rate: 0.0010
# Epoch 2/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.3299 - class_loss: 0.4975 - loss: 2.8274
# Epoch 2: val_loss improved from 2.86981 to 2.78458, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 2: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 2.3032 - class_loss: 0.4843 - loss: 2.7874 - val_box_loss: 2.3206 - val_class_loss: 0.4640 - val_loss: 2.7846 - learning_rate: 0.0010
# Epoch 3/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.2490 - class_loss: 0.4505 - loss: 2.6995
# Epoch 3: val_loss improved from 2.78458 to 2.67225, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 3: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 2.2367 - class_loss: 0.4449 - loss: 2.6815 - val_box_loss: 2.2539 - val_class_loss: 0.4183 - val_loss: 2.6723 - learning_rate: 0.0010
# Epoch 4/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.2070 - class_loss: 0.4276 - loss: 2.6346
# Epoch 4: val_loss improved from 2.67225 to 2.64180, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 4: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 316ms/step - box_loss: 2.1969 - class_loss: 0.4250 - loss: 2.6219 - val_box_loss: 2.2385 - val_class_loss: 0.4033 - val_loss: 2.6418 - learning_rate: 0.0010
# Epoch 5/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.1623 - class_loss: 0.4152 - loss: 2.5775
# Epoch 5: val_loss improved from 2.64180 to 2.59366, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 5: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 317ms/step - box_loss: 2.1595 - class_loss: 0.4122 - loss: 2.5717 - val_box_loss: 2.2050 - val_class_loss: 0.3886 - val_loss: 2.5937 - learning_rate: 0.0010
# Epoch 6/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.1418 - class_loss: 0.4014 - loss: 2.5432
# Epoch 6: val_loss improved from 2.59366 to 2.58007, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 6: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.1316 - class_loss: 0.4009 - loss: 2.5325 - val_box_loss: 2.1934 - val_class_loss: 0.3866 - val_loss: 2.5801 - learning_rate: 0.0010
# Epoch 7/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.1142 - class_loss: 0.3937 - loss: 2.5079
# Epoch 7: val_loss improved from 2.58007 to 2.55393, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 7: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.1149 - class_loss: 0.3937 - loss: 2.5085 - val_box_loss: 2.1727 - val_class_loss: 0.3812 - val_loss: 2.5539 - learning_rate: 0.0010
# Epoch 8/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.1068 - class_loss: 0.3904 - loss: 2.4971
# Epoch 8: val_loss improved from 2.55393 to 2.53212, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 8: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 315ms/step - box_loss: 2.1012 - class_loss: 0.3891 - loss: 2.4903 - val_box_loss: 2.1455 - val_class_loss: 0.3866 - val_loss: 2.5321 - learning_rate: 0.0010
# Epoch 9/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0923 - class_loss: 0.3818 - loss: 2.4741
# Epoch 9: val_loss did not improve from 2.53212
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 316ms/step - box_loss: 2.0891 - class_loss: 0.3818 - loss: 2.4709 - val_box_loss: 2.2124 - val_class_loss: 0.3748 - val_loss: 2.5872 - learning_rate: 0.0010
# Epoch 10/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0737 - class_loss: 0.3774 - loss: 2.4512
# Epoch 10: val_loss improved from 2.53212 to 2.51990, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 10: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.0725 - class_loss: 0.3794 - loss: 2.4519 - val_box_loss: 2.1364 - val_class_loss: 0.3835 - val_loss: 2.5199 - learning_rate: 0.0010
# Epoch 11/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0623 - class_loss: 0.3748 - loss: 2.4371
# Epoch 11: val_loss improved from 2.51990 to 2.48642, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 11: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 316ms/step - box_loss: 2.0586 - class_loss: 0.3755 - loss: 2.4341 - val_box_loss: 2.1143 - val_class_loss: 0.3721 - val_loss: 2.4864 - learning_rate: 0.0010
# Epoch 12/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0500 - class_loss: 0.3713 - loss: 2.4213
# Epoch 12: val_loss did not improve from 2.48642
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.0536 - class_loss: 0.3727 - loss: 2.4263 - val_box_loss: 2.1856 - val_class_loss: 0.3662 - val_loss: 2.5517 - learning_rate: 0.0010
# Epoch 13/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0447 - class_loss: 0.3696 - loss: 2.4144
# Epoch 13: val_loss did not improve from 2.48642
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 2.0446 - class_loss: 0.3693 - loss: 2.4140 - val_box_loss: 2.1953 - val_class_loss: 0.3684 - val_loss: 2.5637 - learning_rate: 0.0010
# Epoch 14/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.0310 - class_loss: 0.3666 - loss: 2.3976
# Epoch 14: val_loss did not improve from 2.48642
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 2.0302 - class_loss: 0.3665 - loss: 2.3967 - val_box_loss: 2.1380 - val_class_loss: 0.3647 - val_loss: 2.5026 - learning_rate: 0.0010
# Epoch 15/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.0331 - class_loss: 0.3657 - loss: 2.3988
# Epoch 15: val_loss improved from 2.48642 to 2.48563, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 15: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.0328 - class_loss: 0.3669 - loss: 2.3997 - val_box_loss: 2.1235 - val_class_loss: 0.3621 - val_loss: 2.4856 - learning_rate: 0.0010
# Epoch 16/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.0191 - class_loss: 0.3630 - loss: 2.3821
# Epoch 16: val_loss did not improve from 2.48563
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 2.0201 - class_loss: 0.3630 - loss: 2.3831 - val_box_loss: 2.1607 - val_class_loss: 0.3670 - val_loss: 2.5277 - learning_rate: 0.0010
# Epoch 17/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0182 - class_loss: 0.3592 - loss: 2.3774
# Epoch 17: val_loss improved from 2.48563 to 2.45232, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 17: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 2.0157 - class_loss: 0.3602 - loss: 2.3759 - val_box_loss: 2.0920 - val_class_loss: 0.3603 - val_loss: 2.4523 - learning_rate: 0.0010
# Epoch 18/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 2.0138 - class_loss: 0.3595 - loss: 2.3733
# Epoch 18: val_loss improved from 2.45232 to 2.44892, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 18: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 315ms/step - box_loss: 2.0093 - class_loss: 0.3587 - loss: 2.3681 - val_box_loss: 2.0841 - val_class_loss: 0.3648 - val_loss: 2.4489 - learning_rate: 0.0010
# Epoch 19/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 2.0037 - class_loss: 0.3563 - loss: 2.3600
# Epoch 19: val_loss did not improve from 2.44892
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9991 - class_loss: 0.3563 - loss: 2.3554 - val_box_loss: 2.1464 - val_class_loss: 0.3591 - val_loss: 2.5055 - learning_rate: 0.0010
# Epoch 20/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9884 - class_loss: 0.3539 - loss: 2.3423
# Epoch 20: val_loss did not improve from 2.44892
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 315ms/step - box_loss: 1.9917 - class_loss: 0.3543 - loss: 2.3460 - val_box_loss: 2.1039 - val_class_loss: 0.3589 - val_loss: 2.4628 - learning_rate: 0.0010
# Epoch 21/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9888 - class_loss: 0.3512 - loss: 2.3401
# Epoch 21: val_loss did not improve from 2.44892
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9868 - class_loss: 0.3522 - loss: 2.3390 - val_box_loss: 2.1432 - val_class_loss: 0.3575 - val_loss: 2.5007 - learning_rate: 0.0010
# Epoch 22/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9884 - class_loss: 0.3528 - loss: 2.3412
# Epoch 22: val_loss improved from 2.44892 to 2.43578, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 22: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9855 - class_loss: 0.3511 - loss: 2.3367 - val_box_loss: 2.0783 - val_class_loss: 0.3574 - val_loss: 2.4358 - learning_rate: 0.0010
# Epoch 23/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9771 - class_loss: 0.3488 - loss: 2.3259
# Epoch 23: val_loss did not improve from 2.43578
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 1.9789 - class_loss: 0.3508 - loss: 2.3297 - val_box_loss: 2.1092 - val_class_loss: 0.3531 - val_loss: 2.4623 - learning_rate: 0.0010
# Epoch 24/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9798 - class_loss: 0.3478 - loss: 2.3276
# Epoch 24: val_loss did not improve from 2.43578
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9802 - class_loss: 0.3494 - loss: 2.3297 - val_box_loss: 2.1036 - val_class_loss: 0.3581 - val_loss: 2.4617 - learning_rate: 0.0010
# Epoch 25/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9718 - class_loss: 0.3490 - loss: 2.3208
# Epoch 25: val_loss did not improve from 2.43578
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9729 - class_loss: 0.3489 - loss: 2.3218 - val_box_loss: 2.1112 - val_class_loss: 0.3585 - val_loss: 2.4697 - learning_rate: 0.0010
# Epoch 26/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9754 - class_loss: 0.3468 - loss: 2.3221
# Epoch 26: val_loss improved from 2.43578 to 2.42528, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 26: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 317ms/step - box_loss: 1.9718 - class_loss: 0.3472 - loss: 2.3190 - val_box_loss: 2.0697 - val_class_loss: 0.3556 - val_loss: 2.4253 - learning_rate: 0.0010
# Epoch 27/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9623 - class_loss: 0.3452 - loss: 2.3075
# Epoch 27: val_loss did not improve from 2.42528
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 560s 315ms/step - box_loss: 1.9642 - class_loss: 0.3459 - loss: 2.3101 - val_box_loss: 2.1245 - val_class_loss: 0.3541 - val_loss: 2.4786 - learning_rate: 0.0010
# Epoch 28/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9627 - class_loss: 0.3450 - loss: 2.3077
# Epoch 28: val_loss did not improve from 2.42528
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9663 - class_loss: 0.3449 - loss: 2.3112 - val_box_loss: 2.1022 - val_class_loss: 0.3525 - val_loss: 2.4547 - learning_rate: 0.0010
# Epoch 29/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9534 - class_loss: 0.3423 - loss: 2.2957
# Epoch 29: val_loss did not improve from 2.42528
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9554 - class_loss: 0.3432 - loss: 2.2987 - val_box_loss: 2.1000 - val_class_loss: 0.3523 - val_loss: 2.4523 - learning_rate: 0.0010
# Epoch 30/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9532 - class_loss: 0.3395 - loss: 2.2928
# Epoch 30: val_loss did not improve from 2.42528
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9522 - class_loss: 0.3409 - loss: 2.2930 - val_box_loss: 2.0929 - val_class_loss: 0.3529 - val_loss: 2.4459 - learning_rate: 0.0010
# Epoch 31/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9434 - class_loss: 0.3414 - loss: 2.2847
# Epoch 31: val_loss did not improve from 2.42528
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9509 - class_loss: 0.3418 - loss: 2.2927 - val_box_loss: 2.0901 - val_class_loss: 0.3491 - val_loss: 2.4392 - learning_rate: 0.0010
# Epoch 32/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9330 - class_loss: 0.3353 - loss: 2.2683
# Epoch 32: val_loss improved from 2.42528 to 2.41731, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 32: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 563s 316ms/step - box_loss: 1.9287 - class_loss: 0.3346 - loss: 2.2633 - val_box_loss: 2.0712 - val_class_loss: 0.3461 - val_loss: 2.4173 - learning_rate: 3.0000e-04
# Epoch 33/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9273 - class_loss: 0.3319 - loss: 2.2592
# Epoch 33: val_loss improved from 2.41731 to 2.40978, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 33: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 316ms/step - box_loss: 1.9247 - class_loss: 0.3318 - loss: 2.2565 - val_box_loss: 2.0628 - val_class_loss: 0.3470 - val_loss: 2.4098 - learning_rate: 3.0000e-04
# Epoch 34/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - box_loss: 1.9245 - class_loss: 0.3305 - loss: 2.2551
# Epoch 34: val_loss did not improve from 2.40978
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 316ms/step - box_loss: 1.9223 - class_loss: 0.3306 - loss: 2.2529 - val_box_loss: 2.0799 - val_class_loss: 0.3441 - val_loss: 2.4240 - learning_rate: 3.0000e-04
# Epoch 35/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9168 - class_loss: 0.3303 - loss: 2.2471
# Epoch 35: val_loss improved from 2.40978 to 2.38992, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 35: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 543s 317ms/step - box_loss: 1.9132 - class_loss: 0.3296 - loss: 2.2428 - val_box_loss: 2.0435 - val_class_loss: 0.3464 - val_loss: 2.3899 - learning_rate: 3.0000e-04
# Epoch 36/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9177 - class_loss: 0.3304 - loss: 2.2481
# Epoch 36: val_loss did not improve from 2.38992
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9139 - class_loss: 0.3308 - loss: 2.2447 - val_box_loss: 2.0613 - val_class_loss: 0.3423 - val_loss: 2.4036 - learning_rate: 3.0000e-04
# Epoch 37/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9154 - class_loss: 0.3291 - loss: 2.2445
# Epoch 37: val_loss did not improve from 2.38992
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 1.9146 - class_loss: 0.3291 - loss: 2.2437 - val_box_loss: 2.0694 - val_class_loss: 0.3460 - val_loss: 2.4154 - learning_rate: 3.0000e-04
# Epoch 38/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9120 - class_loss: 0.3299 - loss: 2.2419
# Epoch 38: val_loss did not improve from 2.38992
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9129 - class_loss: 0.3299 - loss: 2.2428 - val_box_loss: 2.0780 - val_class_loss: 0.3442 - val_loss: 2.4223 - learning_rate: 3.0000e-04
# Epoch 39/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9099 - class_loss: 0.3266 - loss: 2.2366
# Epoch 39: val_loss improved from 2.38992 to 2.38521, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 39: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9156 - class_loss: 0.3284 - loss: 2.2440 - val_box_loss: 2.0410 - val_class_loss: 0.3442 - val_loss: 2.3852 - learning_rate: 3.0000e-04
# Epoch 40/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9134 - class_loss: 0.3288 - loss: 2.2423
# Epoch 40: val_loss did not improve from 2.38521
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.9099 - class_loss: 0.3280 - loss: 2.2379 - val_box_loss: 2.0806 - val_class_loss: 0.3422 - val_loss: 2.4228 - learning_rate: 3.0000e-04
# Epoch 41/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9059 - class_loss: 0.3264 - loss: 2.2323
# Epoch 41: val_loss did not improve from 2.38521
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9093 - class_loss: 0.3282 - loss: 2.2376 - val_box_loss: 2.0444 - val_class_loss: 0.3431 - val_loss: 2.3875 - learning_rate: 3.0000e-04
# Epoch 42/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9011 - class_loss: 0.3275 - loss: 2.2286
# Epoch 42: val_loss did not improve from 2.38521
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 557s 325ms/step - box_loss: 1.9035 - class_loss: 0.3272 - loss: 2.2308 - val_box_loss: 2.0625 - val_class_loss: 0.3421 - val_loss: 2.4046 - learning_rate: 3.0000e-04
# Epoch 43/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9111 - class_loss: 0.3266 - loss: 2.2377
# Epoch 43: val_loss did not improve from 2.38521
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9087 - class_loss: 0.3263 - loss: 2.2351 - val_box_loss: 2.0565 - val_class_loss: 0.3417 - val_loss: 2.3982 - learning_rate: 3.0000e-04
# Epoch 44/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9081 - class_loss: 0.3263 - loss: 2.2344
# Epoch 44: val_loss improved from 2.38521 to 2.38297, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 44: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9049 - class_loss: 0.3269 - loss: 2.2318 - val_box_loss: 2.0409 - val_class_loss: 0.3421 - val_loss: 2.3830 - learning_rate: 3.0000e-04
# Epoch 45/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9082 - class_loss: 0.3249 - loss: 2.2331
# Epoch 45: val_loss improved from 2.38297 to 2.37377, saving model to /kaggle/working/detector_v2_best.weights.h5
#
# Epoch 45: finished saving model to /kaggle/working/detector_v2_best.weights.h5
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9058 - class_loss: 0.3263 - loss: 2.2320 - val_box_loss: 2.0301 - val_class_loss: 0.3437 - val_loss: 2.3738 - learning_rate: 3.0000e-04
# Epoch 46/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8976 - class_loss: 0.3241 - loss: 2.2216
# Epoch 46: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.8987 - class_loss: 0.3260 - loss: 2.2248 - val_box_loss: 2.0396 - val_class_loss: 0.3424 - val_loss: 2.3819 - learning_rate: 3.0000e-04
# Epoch 47/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9042 - class_loss: 0.3257 - loss: 2.2299
# Epoch 47: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 1.8997 - class_loss: 0.3257 - loss: 2.2255 - val_box_loss: 2.0541 - val_class_loss: 0.3430 - val_loss: 2.3971 - learning_rate: 3.0000e-04
# Epoch 48/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.9072 - class_loss: 0.3243 - loss: 2.2315
# Epoch 48: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 561s 315ms/step - box_loss: 1.9064 - class_loss: 0.3252 - loss: 2.2316 - val_box_loss: 2.0447 - val_class_loss: 0.3400 - val_loss: 2.3847 - learning_rate: 3.0000e-04
# Epoch 49/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9034 - class_loss: 0.3249 - loss: 2.2284
# Epoch 49: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 316ms/step - box_loss: 1.9018 - class_loss: 0.3252 - loss: 2.2270 - val_box_loss: 2.0482 - val_class_loss: 0.3430 - val_loss: 2.3912 - learning_rate: 3.0000e-04
# Epoch 50/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.9052 - class_loss: 0.3240 - loss: 2.2292
# Epoch 50: val_loss did not improve from 2.37377
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.9011 - class_loss: 0.3244 - loss: 2.2255 - val_box_loss: 2.0981 - val_class_loss: 0.3416 - val_loss: 2.4397 - learning_rate: 3.0000e-04
# Epoch 51/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8940 - class_loss: 0.3225 - loss: 2.2166
# Epoch 51: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.8918 - class_loss: 0.3222 - loss: 2.2140 - val_box_loss: 2.0413 - val_class_loss: 0.3402 - val_loss: 2.3815 - learning_rate: 9.0000e-05
# Epoch 52/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8899 - class_loss: 0.3229 - loss: 2.2128
# Epoch 52: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 562s 315ms/step - box_loss: 1.8899 - class_loss: 0.3225 - loss: 2.2124 - val_box_loss: 2.0466 - val_class_loss: 0.3389 - val_loss: 2.3855 - learning_rate: 9.0000e-05
# Epoch 53/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.8861 - class_loss: 0.3201 - loss: 2.2062
# Epoch 53: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 540s 315ms/step - box_loss: 1.8854 - class_loss: 0.3200 - loss: 2.2054 - val_box_loss: 2.0462 - val_class_loss: 0.3390 - val_loss: 2.3852 - learning_rate: 9.0000e-05
# Epoch 54/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8970 - class_loss: 0.3231 - loss: 2.2201
# Epoch 54: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 316ms/step - box_loss: 1.8907 - class_loss: 0.3227 - loss: 2.2134 - val_box_loss: 2.0399 - val_class_loss: 0.3396 - val_loss: 2.3795 - learning_rate: 9.0000e-05
# Epoch 55/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8821 - class_loss: 0.3189 - loss: 2.2010
# Epoch 55: val_loss did not improve from 2.37377
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.8832 - class_loss: 0.3197 - loss: 2.2029 - val_box_loss: 2.0456 - val_class_loss: 0.3386 - val_loss: 2.3842 - learning_rate: 9.0000e-05
# Epoch 56/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8857 - class_loss: 0.3217 - loss: 2.2073
# Epoch 56: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 563s 316ms/step - box_loss: 1.8856 - class_loss: 0.3207 - loss: 2.2063 - val_box_loss: 2.0479 - val_class_loss: 0.3382 - val_loss: 2.3861 - learning_rate: 2.7000e-05
# Epoch 57/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step - box_loss: 1.8929 - class_loss: 0.3199 - loss: 2.2129
# Epoch 57: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 542s 316ms/step - box_loss: 1.8864 - class_loss: 0.3200 - loss: 2.2064 - val_box_loss: 2.0497 - val_class_loss: 0.3382 - val_loss: 2.3879 - learning_rate: 2.7000e-05
# Epoch 58/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.8883 - class_loss: 0.3201 - loss: 2.2084
# Epoch 58: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.8876 - class_loss: 0.3207 - loss: 2.2083 - val_box_loss: 2.0420 - val_class_loss: 0.3385 - val_loss: 2.3805 - learning_rate: 2.7000e-05
# Epoch 59/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.8893 - class_loss: 0.3207 - loss: 2.2100
# Epoch 59: val_loss did not improve from 2.37377
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 539s 315ms/step - box_loss: 1.8882 - class_loss: 0.3208 - loss: 2.2090 - val_box_loss: 2.0517 - val_class_loss: 0.3377 - val_loss: 2.3894 - learning_rate: 2.7000e-05
# Epoch 60/60
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step - box_loss: 1.8822 - class_loss: 0.3197 - loss: 2.2018
# Epoch 60: val_loss did not improve from 2.37377
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 1711/1711 ━━━━━━━━━━━━━━━━━━━━ 541s 315ms/step - box_loss: 1.8824 - class_loss: 0.3205 - loss: 2.2029 - val_box_loss: 2.0487 - val_class_loss: 0.3382 - val_loss: 2.3869 - learning_rate: 2.7000e-05
# Epoch 60: early stopping
# Best validation model: epoch 45  - val_loss 2.3737738132476807
# Best V2 weights: /kaggle/working/detector_v2_best.weights.h5

# %% [markdown]
# #### Validacion
#
# Se evaluan las detecciones con las mismas metricas que en la primera prueba para comparar ambas configuraciones.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as col
import numpy as np
# %matplotlib inline

def area_intersection(boxes, box):
    xmin = np.maximum(np.min(boxes[:, 0::2], axis=1), np.min(box[0::2]))
    ymin = np.maximum(np.min(boxes[:, 1::2], axis=1), np.min(box[1::2]))
    xmax = np.minimum(np.max(boxes[:, 0::2], axis=1), np.max(box[0::2]))
    ymax = np.minimum(np.max(boxes[:, 1::2], axis=1), np.max(box[1::2]))
    w = np.maximum(xmax - xmin + 1.0, 0.0)
    h = np.maximum(ymax - ymin + 1.0, 0.0)
    return w * h

def area_union(boxes, box):
    area_anns = (np.max(box[0::2])-np.min(box[0::2])+1.0) * (np.max(box[1::2])-np.min(box[1::2])+1.0)
    area_pred = (np.max(boxes[:, 0::2], axis=1)-np.min(boxes[:, 0::2], axis=1)+1.0) * (np.max(boxes[:, 1::2], axis=1)-np.min(boxes[:, 1::2], axis=1)+1.0)
    return area_anns + area_pred - area_intersection(boxes, box)

def calc_iou(boxes, box):
    iou = area_intersection(boxes, box) / area_union(boxes, box)
    max_value = np.max(iou)
    max_index = np.argmax(iou)
    return max_value, max_index

def calc_ap(rec, prec):
    # First append sentinel values at the end
    mrec = np.concatenate(([0.0], rec, [1.0]))
    mpre = np.concatenate(([0.0], prec, [0.0]))
    # Compute the precision envelope
    for i in range(mpre.size-1, 0, -1):
        mpre[i-1] = np.maximum(mpre[i-1], mpre[i])
    # To calculate area under PR curve, look for points where X axis (recall) changes value
    i = np.where(mrec[1:] != mrec[:-1])[0]
    # and sum (\Delta recall) * prec
    ap = np.sum((mrec[i+1] - mrec[i]) * mpre[i+1])
    return ap

def draw_confusion_matrix(cm, categories):
    # Draw confusion matrix
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    cm = cm.astype('float') / np.maximum(cm.sum(axis=1)[:, np.newaxis], np.finfo(np.float64).eps)
    im = ax.imshow(cm, interpolation='nearest', cmap=plt.cm.get_cmap('Blues'))
    ax.figure.colorbar(im, ax=ax)
    ax.set(xticks=np.arange(cm.shape[1]), yticks=np.arange(cm.shape[0]), xticklabels=categories, yticklabels=categories, ylabel='Annotation', xlabel='Prediction')
    # Rotate the tick labels and set their alignment
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right", rotation_mode="anchor")
    # Loop over data dimensions and create text annotations
    thresh = cm.max() / 2.0
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], '.2f'), ha="center", va="center", color="white" if cm[i, j] > thresh else "black", fontsize=int(20-pow(len(categories), 0.5)))
    fig.tight_layout()
    plt.show()

def draw_precision_recall(precisions, recalls, categories):
    # Draw precision-recall curves for each category
    fig = plt.figure(figsize=[6.4*pow(len(categories), 0.5), 4.8*pow(len(categories), 0.5)])
    ax = fig.add_subplot(111)
    plt.axis([0, 1, 0, 1])
    c_dark = list(filter(lambda x: x.startswith('dark'), col.cnames.keys()))
    aps = []
    # Compare categories for a specific algorithm
    for idx in range(len(categories)):
        plt.plot(recalls[idx], precisions[idx], color=c_dark[idx], label=categories[idx], linewidth=4.0)
        aps.append(calc_ap(recalls[idx], precisions[idx]))
    handles, labels = ax.get_legend_handles_labels()
    labels = [str(val + ' [' + "{:.3f}".format(aps[idx]) + ']') for idx, val in enumerate(labels)]
    handles = [h for (ap, h) in sorted(zip(aps, handles), key=lambda x: x[0], reverse=True)]
    labels = [l for (ap, l) in sorted(zip(aps, labels), key=lambda x: x[0], reverse=True)]
    leg = plt.legend(handles, labels, loc='upper right')
    leg.set_zorder(100)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.grid("on", linestyle="--", linewidth=2.0)
    fig.tight_layout()
    plt.show()

# %%
import numpy as np
from tqdm import tqdm

model.load_weights(str(get_available_weights_path(required=True)))
# Generate the list of objects from annotations
ds_valid = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_valid, tf.string), tf.cast(tiles_valid, tf.int32), tf.cast(tf.ragged.constant(bboxes_valid), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_valid), tf.float32).to_tensor()))
ds_valid = ds_valid.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_valid = ds_valid.batch(batch_size=1)
ds_valid = ds_valid.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_valid)
annotations, predictions = {}, {}
for ann in tqdm(anns_valid):
    # Save annotations
    annotations.setdefault(ann.filename, {})
    predictions.setdefault(ann.filename, {})
    for obj in ann.objects:
        annotations[ann.filename].setdefault(obj.category, {'bbox': []})
        annotations[ann.filename][obj.category]['bbox'].append(obj.bb)
    # Save prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Out:
# 100%|██████████| 761/761 [01:55<00:00,  6.58it/s]

# %%
threshold = 0.5
default_cls = 'BACKGROUND'
y_true, y_pred = [], []  # confusion matrix
tps, confidences = dict(), dict()  # draw precision-recall curves for each category
for cls in categories.values():
    # Compute TP, FP and FN for each image
    tps[cls], confidences[cls] = [], []
    for f in predictions:
        # Sort 'cls' predictions by confidence for each file
        pred_boxes, pred_confidences = [], []
        if cls in predictions[f].keys():
            for idx in range(len(predictions[f][cls]['bbox'])):
                pred_boxes.append(predictions[f][cls]['bbox'][idx])
                pred_confidences.append(predictions[f][cls]['confidence'][idx])
            sorted_ind = np.argsort(-np.array(pred_confidences))
            pred_boxes = np.array(pred_boxes)[sorted_ind, :]
        pred_boxes = np.array(pred_boxes).astype(float)
        # Define 'cls' annotations for each file
        anno_boxes = []
        if cls in annotations[f].keys():
            anno_boxes = annotations[f][cls]['bbox']
        anno_boxes = np.array(anno_boxes).astype(float)
        # Define horizontal or oriented bounding boxes
        anno_indices = list(range(len(anno_boxes)))
        # Compare a single prediction 'pred_box' with all annotations 'anno_boxes'
        for pred_idx, pred_box in enumerate(pred_boxes):
            # A prediction is correct if its IoU with the ground truth is above the threshold
            iou_value, ann_index = calc_iou(anno_boxes, pred_box) if len(anno_boxes) > 0 else (-1, -1)
            if iou_value > threshold and ann_index in anno_indices:
                # TP
                anno_indices.remove(int(ann_index))
                tps[cls] += [1.0]
                y_true += [cls]
            else:
                # FP
                tps[cls] += [0.0]
                y_true += [default_cls]
            y_pred += [cls]
            confidences[cls] += [pred_confidences[pred_idx]]
        # FN
        y_true += [cls] * len(anno_indices)
        y_pred += [default_cls] * len(anno_indices)
y_true, y_pred = np.array(y_true), np.array(y_pred)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score

# Compute AP metric
precision_list, recall_list, ap_list = [], [], []
for cls in categories.values():
    sorted_ind = np.argsort(-np.array(confidences[cls]))
    tp = np.cumsum(np.array(tps[cls])[sorted_ind], dtype=float)
    recall = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(np.sum(y_true == cls), np.finfo(np.float64).eps)
    precision = np.array([0.0]) if len(tp) == 0 else tp / np.maximum(list(range(1, np.sum(y_pred == cls)+1)), np.finfo(np.float64).eps)
    ap = calc_ap(recall, precision)
    print('> %s: Recall: %.3f%% Precision: %.3f%% AP: %.3f%%' % (cls, recall[-1]*100, precision[-1]*100, ap*100))
    precision_list.append(precision)
    recall_list.append(recall)
    ap_list.append(ap)
mean_ap = np.mean(ap_list)
print('mAccuracy: %.3f%%' % (accuracy_score(y_true, y_pred)*100))
print('mRecall: %.3f%%' % (recall_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mPrecision: %.3f%%' % (precision_score(y_true, y_pred, average='macro', zero_division=1)*100))
print('mAP: %.3f%%' % (mean_ap*100))
# Out:
# > Small car: Recall: 31.324% Precision: 31.726% AP: 20.164%
# > Bus: Recall: 18.125% Precision: 22.180% AP: 7.369%
# > Truck: Recall: 7.950% Precision: 12.691% AP: 2.143%
# > Building: Recall: 55.786% Precision: 43.357% AP: 45.259%
# mAccuracy: 26.592%
# mRecall: 22.637%
# mPrecision: 21.991%
# mAP: 18.734%

# %%
names = list(categories.values()).copy()
names.insert(0, default_cls)
cm = confusion_matrix(y_true, y_pred, labels=names)
print('Confusion matrix:')
print(cm)
draw_confusion_matrix(cm, names)
draw_precision_recall(precision_list, recall_list, categories)
# Out:
# Confusion matrix:
# [[    0 11797   407   571 20929]
#  [12019  5482     0     0     0]
#  [  524     0   116     0     0]
#  [  961     0     0    83     0]
#  [12697     0     0     0 16020]]

# %% [markdown]
# #### Prueba sobre test y fichero de entrega
#
# Se aplica el modelo al conjunto de test y se empaqueta la prediccion final de esta iteracion.

# %%
import numpy as np

anns = []
if not TEST_DIR.exists():
    raise FileNotFoundError(f'No se encontro la carpeta de test: {TEST_DIR}')

for path in sorted(TEST_DIR.rglob('*.tif')):
    image = GenericImage(path.relative_to(DATA_ROOT).as_posix())
    image.tile = np.array([0, 0, 640, 640])
    anns.append(image)

print('Number of testing images: ' + str(len(anns)))
# Out:
# Number of testing images: 852

# %%
import numpy as np
from tqdm import tqdm

model.load_weights(str(get_available_weights_path(required=True)))
# Generate the list of objects from annotations
filenames_test, tiles_test, bboxes_test, categories_test = zip(*list(map(lambda img_ann: (img_ann.filename, list(img_ann.tile), list([list(obj_ann.bb) for obj_ann in img_ann.objects]), list([list(categories.keys())[list(categories.values()).index(obj_ann.category)] for obj_ann in img_ann.objects])), anns)))
ds_test = tf.data.Dataset.from_tensor_slices((tf.cast(filenames_test, tf.string), tf.cast(tiles_test, tf.int32), tf.cast(tf.ragged.constant(bboxes_test), tf.float32).to_tensor(), tf.cast(tf.ragged.constant(categories_test), tf.float32).to_tensor()))
ds_test = ds_test.map(image_generator, num_parallel_calls=tf.data.AUTOTUNE).cache()
ds_test = ds_test.batch(batch_size=1)
ds_test = ds_test.map(dict_to_tuple, num_parallel_calls=tf.data.AUTOTUNE).prefetch(tf.data.AUTOTUNE)
# Process each tile sequentially
iterator = iter(ds_test)
predictions = {}
for ann in tqdm(anns):
    # Generate prediction
    image, _ = next(iterator)
    y_pred = model.predict(image, verbose=0)
    predictions.setdefault(ann.filename, {})
    for i in range(np.squeeze(y_pred['num_detections'])):
        obj = GenericObject()
        bbox = np.squeeze(y_pred['boxes'])[i]
        obj.bb = (bbox[0], bbox[1], bbox[2], bbox[3])
        obj.category = categories[np.squeeze(y_pred['classes'])[i]]
        obj.score = np.squeeze(y_pred['confidence'])[i]
        predictions[ann.filename].setdefault(obj.category, {'bbox': [], 'confidence': []})
        predictions[ann.filename][obj.category]['bbox'].append(obj.bb)
        predictions[ann.filename][obj.category]['confidence'].append(obj.score)  # sort detections by confidence
# Save prediction
predictions_data = {"images": {}, "annotations": {}, "categories": {}}
predictions_data["categories"] = categories
imgs_idx, annos_idx = 0, 0
for pred in predictions:
    num_objects = 0
    for cat in predictions[pred]:
        for bb in predictions[pred][cat]['bbox']:
            num_objects += len(predictions[pred][cat]['bbox'])
    image_data = {"image_id": pred.split('/')[-1], "filename": pred, "num_objects": num_objects, "width": 640, "height": 640}
    predictions_data["images"][imgs_idx] = image_data
    imgs_idx += 1
    bboxes, confs = [], []
    for cat in predictions[pred]:
        for i in range(len(predictions[pred][cat]['bbox'])):  
            bbox = predictions[pred][cat]['bbox'][i]
            conf = predictions[pred][cat]['confidence'][i]
            annotation_data = {"image_id": pred.split('/')[-1], "category_id": cat, "bbox": (int(bbox[0]), int(bbox[1]), int(bbox[2]), int(bbox[3])), "confidence": float(conf)}
            predictions_data["annotations"][annos_idx] = annotation_data
            annos_idx += 1
# Out:
# 100%|██████████| 852/852 [02:04<00:00,  6.82it/s]

# %%
import json
import zipfile
from IPython.display import FileLink, display

prediction_path = WORKDIR / 'prediction_v2.json'
submission_path = WORKDIR / 'submission_v2.zip'

with open(prediction_path, 'w') as outfile:
    json.dump(predictions_data, outfile)

with zipfile.ZipFile(submission_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    zf.write(prediction_path, arcname='prediction.json')

print('Archivos generados:')
print(prediction_path, '-', prediction_path.stat().st_size, 'bytes')
print(submission_path, '-', submission_path.stat().st_size, 'bytes')
display(FileLink(str(submission_path)))
# Out:
# Archivos generados:
# /kaggle/working/prediction_v2.json - 10787478 bytes
# /kaggle/working/submission_v2.zip - 1676038 bytes
# /kaggle/working/submission_v2.zip
