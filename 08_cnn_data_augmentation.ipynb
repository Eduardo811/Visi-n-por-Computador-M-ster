# %% [markdown]
# # 08 - CNN con data augmentation usando arrays
#
# CNN regularizada que anade aumentos de datos dentro del modelo y usa el dataset preprocesado de arrays (`X_all.npy`) para evitar leer miles de `.tif` durante el entrenamiento.

# %% [markdown]
# ## Librerias y configuracion

# %%
import json
import time
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

RUN_START = time.perf_counter()

print('GPUs disponibles:', tf.config.list_physical_devices('GPU'))
# Out:
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
SEED = 42
BATCH_SIZE = 32
EPOCHS = 40
VALIDATION_SIZE = 0.15
IMAGE_SHAPE = (224, 224, 3)

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Datos

# %% [markdown]
# ### Localizacion de inputs

# %%
KAGGLE_INPUT_DIR = Path('/kaggle/input')
WORKDIR = Path('/kaggle/working')

if not KAGGLE_INPUT_DIR.exists():
    raise FileNotFoundError('No existe /kaggle/input. Ejecuta este notebook en Kaggle.')

array_matches = sorted(KAGGLE_INPUT_DIR.rglob('X_all.npy'))
working_candidate = WORKDIR / 'xview_arrays' / 'X_all.npy'
if working_candidate.exists():
    array_matches = [working_candidate] + array_matches

if not array_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(
        'No se encontro X_all.npy. Anade el dataset xview_arrays creado con 00_1. '
        f'Inputs disponibles: {available_inputs}'
    )

ARRAYS_ROOT = array_matches[0].parent

json_matches = sorted(KAGGLE_INPUT_DIR.rglob('xview_ann_train.json'))
if not json_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(
        'No se encontro xview_ann_train.json. Anade tambien el dataset original xview_recognition. '
        f'Inputs disponibles: {available_inputs}'
    )

ANN_JSON = json_matches[0]
DATA_ROOT = ANN_JSON.parent
TRAIN_DIR = DATA_ROOT / 'xview_train'
TEST_DIR = DATA_ROOT / 'xview_test'

print('ARRAYS_ROOT:', ARRAYS_ROOT)
print('DATA_ROOT:', DATA_ROOT)
print('ANN_JSON:', ANN_JSON)
print('TRAIN_DIR exists:', TRAIN_DIR.exists())
print('TEST_DIR exists:', TEST_DIR.exists())
# Out:
# ARRAYS_ROOT: /kaggle/input/datasets/eccvdl/xview-arrays/xview_arrays
# DATA_ROOT: /kaggle/input/datasets/eccvdl/xview-recognition
# ANN_JSON: /kaggle/input/datasets/eccvdl/xview-recognition/xview_ann_train.json
# TRAIN_DIR exists: True
# TEST_DIR exists: True

# %% [markdown]
# ### Lectura de arrays

# %%
DATA_LOAD_START = time.perf_counter()

X_all = np.load(ARRAYS_ROOT / 'X_all.npy')
y_all_idx = np.load(ARRAYS_ROOT / 'y_all_idx.npy')
filenames = np.load(ARRAYS_ROOT / 'filenames.npy')
image_ids = np.load(ARRAYS_ROOT / 'image_ids.npy')
category_names = np.load(ARRAYS_ROOT / 'category_names.npy').astype(str).tolist()
num_classes = len(category_names)

print('X_all:', X_all.shape, X_all.dtype, 'RAM aprox:', X_all.nbytes / 1024**3, 'GB')
print('y_all_idx:', y_all_idx.shape, y_all_idx.dtype)
print('filenames:', filenames.shape)
print('image_ids:', image_ids.shape)
print('num_classes:', num_classes)
print(category_names)
# Out:
# X_all: (18746, 224, 224, 3) uint8 RAM aprox: 2.6280040740966797 GB
# y_all_idx: (18746,) int32
# filenames: (18746,)
# image_ids: (18746,)
# num_classes: 13
# ['Cargo plane', 'Small car', 'Bus', 'Truck', 'Motorboat', 'Fishing vessel', 'Dump truck', 'Excavator', 'Building', 'Helipad', 'Storage tank', 'Shipping container', 'Pylon']

# %% [markdown]
# ### Comprobacion de una imagen

# %%
sample_idx = 0
sample_img = X_all[sample_idx]
sample_label_idx = int(y_all_idx[sample_idx])

print('Filename:', filenames[sample_idx])
print('Image id:', image_ids[sample_idx])
print('Shape:', sample_img.shape)
print('Dtype:', sample_img.dtype)
print('Min / Max:', sample_img.min(), sample_img.max())
print('Etiqueta:', category_names[sample_label_idx])
print('Primeros pixeles del array original:')
print(sample_img[:3, :3, :])
print('Primeros pixeles normalizados:')
print((sample_img.astype(np.float32) / 255.0)[:3, :3, :])

plt.figure(figsize=(4, 4))
plt.imshow(sample_img)
plt.title(category_names[sample_label_idx])
plt.axis('off')
plt.show()
# Out:
# Filename: xview_train/Building/0234476c-a017-4c9b-bd2f-872193076cca.tif
# Image id: 0234476c-a017-4c9b-bd2f-872193076cca.tif
# Shape: (224, 224, 3)
# Dtype: uint8
# Min / Max: 0 86
# Etiqueta: Building
# Primeros pixeles del array original:
# [[[45 30 19]
#   [45 30 19]
#   [46 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]]
# Primeros pixeles normalizados:
# [[[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.18039216 0.11764706 0.07450981]]
#
#  [[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]]
#
#  [[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]]]

# %% [markdown]
# ### Split train/valid

# %%
indices = np.arange(len(X_all))
train_idx, val_idx = train_test_split(
    indices,
    test_size=VALIDATION_SIZE,
    random_state=SEED,
    shuffle=True,
    stratify=y_all_idx,
)

X_train = X_all[train_idx]
X_valid = X_all[val_idx]
y_train_idx = y_all_idx[train_idx]
y_valid_idx = y_all_idx[val_idx]

y_train = tf.keras.utils.to_categorical(y_train_idx, num_classes=num_classes).astype(np.float32)
y_valid = tf.keras.utils.to_categorical(y_valid_idx, num_classes=num_classes).astype(np.float32)

DATA_LOAD_TIME = time.perf_counter() - DATA_LOAD_START

print('X_train:', X_train.shape, X_train.dtype, 'RAM aprox:', X_train.nbytes / 1024**3, 'GB')
print('X_valid:', X_valid.shape, X_valid.dtype, 'RAM aprox:', X_valid.nbytes / 1024**3, 'GB')
print('y_train:', y_train.shape, y_train.dtype)
print('y_valid:', y_valid.shape, y_valid.dtype)
print(f'Tiempo carga arrays/split: {DATA_LOAD_TIME:.2f} s')
# Out:
# X_train: (15934, 224, 224, 3) uint8 RAM aprox: 2.2337894439697266 GB
# X_valid: (2812, 224, 224, 3) uint8 RAM aprox: 0.3942146301269531 GB
# y_train: (15934, 13) float32
# y_valid: (2812, 13) float32
# Tiempo carga arrays/split: 1.92 s

# %% [markdown]
# ## Red

# %% [markdown]
# ### Data augmentation y modelo

# %%
L2 = 1e-4

data_aug = tf.keras.Sequential([
    tf.keras.layers.RandomFlip('horizontal_and_vertical'),
    tf.keras.layers.RandomRotation(0.10),
    tf.keras.layers.RandomZoom(0.10),
], name='data_augmentation')

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=IMAGE_SHAPE),
    tf.keras.layers.Rescaling(1.0 / 255.0),
    data_aug,

    tf.keras.layers.Conv2D(32, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax'),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(5e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model.summary()
# Out:
# I0000 00:00:1780347809.915569      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780347809.919006      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ data_augmentation (Sequential)  │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 458,221 (1.75 MB)
#  Trainable params: 457,773 (1.75 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Callbacks

# %%
MODEL_PATH = WORKDIR / '08_cnn_data_augmentation_arrays.keras'

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(str(MODEL_PATH), monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-7, verbose=1),
    tf.keras.callbacks.TerminateOnNaN(),
]

# %% [markdown]
# ### Entrenamiento

# %%
TRAIN_START = time.perf_counter()

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

TRAIN_TIME = time.perf_counter() - TRAIN_START

best_idx = int(np.argmax(history.history['val_accuracy']))
best_value = float(np.max(history.history['val_accuracy']))
print('Best validation model: epoch', best_idx + 1, '- val_accuracy', best_value)
print(f'Tiempo entrenamiento: {TRAIN_TIME:.2f} s')
# Out:
# Epoch 1/40
# I0000 00:00:1780347822.360728     129 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.2549 - loss: 2.2373
# Epoch 1: val_accuracy improved from None to 0.22475, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 1: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 69s 121ms/step - accuracy: 0.2881 - loss: 2.1216 - val_accuracy: 0.2248 - val_loss: 2.2362 - learning_rate: 5.0000e-04
# Epoch 2/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.3431 - loss: 1.9615
# Epoch 2: val_accuracy improved from 0.22475 to 0.38869, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 2: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 60s 121ms/step - accuracy: 0.3540 - loss: 1.9208 - val_accuracy: 0.3887 - val_loss: 1.7972 - learning_rate: 5.0000e-04
# Epoch 3/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.3782 - loss: 1.8371
# Epoch 3: val_accuracy improved from 0.38869 to 0.40292, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 3: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 127ms/step - accuracy: 0.3904 - loss: 1.8021 - val_accuracy: 0.4029 - val_loss: 1.7092 - learning_rate: 5.0000e-04
# Epoch 4/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4096 - loss: 1.7462
# Epoch 4: val_accuracy improved from 0.40292 to 0.45839, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 4: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4180 - loss: 1.7203 - val_accuracy: 0.4584 - val_loss: 1.5938 - learning_rate: 5.0000e-04
# Epoch 5/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4346 - loss: 1.6852
# Epoch 5: val_accuracy improved from 0.45839 to 0.47440, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 5: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4432 - loss: 1.6581 - val_accuracy: 0.4744 - val_loss: 1.5755 - learning_rate: 5.0000e-04
# Epoch 6/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4556 - loss: 1.6341
# Epoch 6: val_accuracy improved from 0.47440 to 0.47511, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 6: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4637 - loss: 1.6093 - val_accuracy: 0.4751 - val_loss: 1.5355 - learning_rate: 5.0000e-04
# Epoch 7/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.4682 - loss: 1.5851
# Epoch 7: val_accuracy did not improve from 0.47511
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4748 - loss: 1.5631 - val_accuracy: 0.4662 - val_loss: 1.5624 - learning_rate: 5.0000e-04
# Epoch 8/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4871 - loss: 1.5451
# Epoch 8: val_accuracy improved from 0.47511 to 0.51885, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 8: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4888 - loss: 1.5216 - val_accuracy: 0.5188 - val_loss: 1.4446 - learning_rate: 5.0000e-04
# Epoch 9/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.4952 - loss: 1.5142
# Epoch 9: val_accuracy improved from 0.51885 to 0.55974, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 9: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.4982 - loss: 1.5003 - val_accuracy: 0.5597 - val_loss: 1.3738 - learning_rate: 5.0000e-04
# Epoch 10/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5036 - loss: 1.4861
# Epoch 10: val_accuracy did not improve from 0.55974
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5107 - loss: 1.4702 - val_accuracy: 0.4936 - val_loss: 1.5079 - learning_rate: 5.0000e-04
# Epoch 11/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5103 - loss: 1.4717
# Epoch 11: val_accuracy did not improve from 0.55974
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5175 - loss: 1.4571 - val_accuracy: 0.4883 - val_loss: 1.5820 - learning_rate: 5.0000e-04
# Epoch 12/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5173 - loss: 1.4447
# Epoch 12: val_accuracy did not improve from 0.55974
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5240 - loss: 1.4307 - val_accuracy: 0.5558 - val_loss: 1.3558 - learning_rate: 5.0000e-04
# Epoch 13/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5268 - loss: 1.4270
# Epoch 13: val_accuracy did not improve from 0.55974
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5308 - loss: 1.4168 - val_accuracy: 0.5352 - val_loss: 1.3954 - learning_rate: 5.0000e-04
# Epoch 14/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5343 - loss: 1.4155
# Epoch 14: val_accuracy improved from 0.55974 to 0.57468, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 14: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5372 - loss: 1.4005 - val_accuracy: 0.5747 - val_loss: 1.3289 - learning_rate: 5.0000e-04
# Epoch 15/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5358 - loss: 1.4071
# Epoch 15: val_accuracy did not improve from 0.57468
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5396 - loss: 1.3885 - val_accuracy: 0.5583 - val_loss: 1.3636 - learning_rate: 5.0000e-04
# Epoch 16/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5405 - loss: 1.3956
# Epoch 16: val_accuracy did not improve from 0.57468
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5446 - loss: 1.3827 - val_accuracy: 0.5573 - val_loss: 1.3472 - learning_rate: 5.0000e-04
# Epoch 17/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5475 - loss: 1.3841
# Epoch 17: val_accuracy improved from 0.57468 to 0.57610, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 17: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5477 - loss: 1.3729 - val_accuracy: 0.5761 - val_loss: 1.3079 - learning_rate: 5.0000e-04
# Epoch 18/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5462 - loss: 1.3724
# Epoch 18: val_accuracy did not improve from 0.57610
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5491 - loss: 1.3621 - val_accuracy: 0.5711 - val_loss: 1.3420 - learning_rate: 5.0000e-04
# Epoch 19/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5512 - loss: 1.3692
# Epoch 19: val_accuracy improved from 0.57610 to 0.60242, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 19: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5522 - loss: 1.3590 - val_accuracy: 0.6024 - val_loss: 1.2440 - learning_rate: 5.0000e-04
# Epoch 20/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5592 - loss: 1.3493
# Epoch 20: val_accuracy did not improve from 0.60242
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5582 - loss: 1.3464 - val_accuracy: 0.5704 - val_loss: 1.3278 - learning_rate: 5.0000e-04
# Epoch 21/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5569 - loss: 1.3424
# Epoch 21: val_accuracy did not improve from 0.60242
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5609 - loss: 1.3398 - val_accuracy: 0.5967 - val_loss: 1.2620 - learning_rate: 5.0000e-04
# Epoch 22/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5591 - loss: 1.3441
# Epoch 22: val_accuracy did not improve from 0.60242
#
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5623 - loss: 1.3350 - val_accuracy: 0.5754 - val_loss: 1.3141 - learning_rate: 5.0000e-04
# Epoch 23/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5788 - loss: 1.2908
# Epoch 23: val_accuracy improved from 0.60242 to 0.61060, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 23: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5851 - loss: 1.2756 - val_accuracy: 0.6106 - val_loss: 1.2094 - learning_rate: 1.5000e-04
# Epoch 24/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.5806 - loss: 1.2807
# Epoch 24: val_accuracy did not improve from 0.61060
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5848 - loss: 1.2707 - val_accuracy: 0.6024 - val_loss: 1.2223 - learning_rate: 1.5000e-04
# Epoch 25/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5858 - loss: 1.2610
# Epoch 25: val_accuracy improved from 0.61060 to 0.61202, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 25: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5899 - loss: 1.2557 - val_accuracy: 0.6120 - val_loss: 1.2122 - learning_rate: 1.5000e-04
# Epoch 26/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5960 - loss: 1.2507
# Epoch 26: val_accuracy improved from 0.61202 to 0.61807, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 26: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5913 - loss: 1.2485 - val_accuracy: 0.6181 - val_loss: 1.1958 - learning_rate: 1.5000e-04
# Epoch 27/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5955 - loss: 1.2566
# Epoch 27: val_accuracy improved from 0.61807 to 0.62055, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 27: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5956 - loss: 1.2447 - val_accuracy: 0.6206 - val_loss: 1.1982 - learning_rate: 1.5000e-04
# Epoch 28/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5857 - loss: 1.2524
# Epoch 28: val_accuracy did not improve from 0.62055
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5901 - loss: 1.2442 - val_accuracy: 0.6170 - val_loss: 1.2031 - learning_rate: 1.5000e-04
# Epoch 29/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.5975 - loss: 1.2454
# Epoch 29: val_accuracy did not improve from 0.62055
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.5957 - loss: 1.2403 - val_accuracy: 0.6056 - val_loss: 1.2328 - learning_rate: 1.5000e-04
# Epoch 30/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6026 - loss: 1.2241
# Epoch 30: val_accuracy improved from 0.62055 to 0.62838, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 30: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6036 - loss: 1.2177 - val_accuracy: 0.6284 - val_loss: 1.1631 - learning_rate: 4.5000e-05
# Epoch 31/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6033 - loss: 1.2146
# Epoch 31: val_accuracy did not improve from 0.62838
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6022 - loss: 1.2178 - val_accuracy: 0.6262 - val_loss: 1.1682 - learning_rate: 4.5000e-05
# Epoch 32/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6060 - loss: 1.2052
# Epoch 32: val_accuracy improved from 0.62838 to 0.62873, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 32: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6062 - loss: 1.2056 - val_accuracy: 0.6287 - val_loss: 1.1690 - learning_rate: 4.5000e-05
# Epoch 33/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6025 - loss: 1.2105
# Epoch 33: val_accuracy did not improve from 0.62873
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6046 - loss: 1.2111 - val_accuracy: 0.6252 - val_loss: 1.1621 - learning_rate: 4.5000e-05
# Epoch 34/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6102 - loss: 1.2047
# Epoch 34: val_accuracy did not improve from 0.62873
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6067 - loss: 1.2035 - val_accuracy: 0.6270 - val_loss: 1.1615 - learning_rate: 4.5000e-05
# Epoch 35/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6044 - loss: 1.2048
# Epoch 35: val_accuracy improved from 0.62873 to 0.63265, saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
#
# Epoch 35: finished saving model to /kaggle/working/08_cnn_data_augmentation_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 127ms/step - accuracy: 0.6037 - loss: 1.2017 - val_accuracy: 0.6326 - val_loss: 1.1553 - learning_rate: 4.5000e-05
# Epoch 36/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6048 - loss: 1.2077
# Epoch 36: val_accuracy did not improve from 0.63265
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6056 - loss: 1.2037 - val_accuracy: 0.6305 - val_loss: 1.1586 - learning_rate: 4.5000e-05
# Epoch 37/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6060 - loss: 1.2063
# Epoch 37: val_accuracy did not improve from 0.63265
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6069 - loss: 1.2057 - val_accuracy: 0.6280 - val_loss: 1.1602 - learning_rate: 4.5000e-05
# Epoch 38/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6046 - loss: 1.2050
# Epoch 38: val_accuracy did not improve from 0.63265
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1.3500000204658135e-05.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6038 - loss: 1.2027 - val_accuracy: 0.6273 - val_loss: 1.1667 - learning_rate: 4.5000e-05
# Epoch 39/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.6047 - loss: 1.2010
# Epoch 39: val_accuracy did not improve from 0.63265
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6088 - loss: 1.1950 - val_accuracy: 0.6312 - val_loss: 1.1521 - learning_rate: 1.3500e-05
# Epoch 40/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.6058 - loss: 1.1963
# Epoch 40: val_accuracy did not improve from 0.63265
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 63s 126ms/step - accuracy: 0.6078 - loss: 1.1941 - val_accuracy: 0.6319 - val_loss: 1.1514 - learning_rate: 1.3500e-05
# Restoring model weights from the end of the best epoch: 35.
# Best validation model: epoch 35 - val_accuracy 0.6326457858085632
# Tiempo entrenamiento: 2526.71 s

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### Graficas

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.title('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predicciones de validacion

# %%
model.load_weights(MODEL_PATH)

valid_loss, valid_accuracy = model.evaluate(X_valid, y_valid, batch_size=BATCH_SIZE, verbose=1)
print('Validation loss:', valid_loss)
print('Validation accuracy:', valid_accuracy)

probs = model.predict(X_valid, batch_size=BATCH_SIZE, verbose=1)
y_pred_idx = np.argmax(probs, axis=1)
y_true_idx = y_valid_idx
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.6326 - loss: 1.1553
# Validation loss: 1.155287504196167
# Validation accuracy: 0.6326457858085632
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step

# %% [markdown]
# ### Matriz de confusion

# %%
cm = confusion_matrix(y_true_idx, y_pred_idx, labels=list(range(num_classes)))

def draw_confusion_matrix_percent(cm, labels):
    cm_norm = cm.astype(float) / np.maximum(cm.sum(axis=1, keepdims=True), np.finfo(np.float64).eps)

    fig, ax = plt.subplots(figsize=(14, 12))
    im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.colormaps['Blues'], vmin=0.0, vmax=max(0.01, cm_norm.max()))
    fig.colorbar(im, ax=ax)

    ax.set(
        xticks=np.arange(len(labels)),
        yticks=np.arange(len(labels)),
        xticklabels=labels,
        yticklabels=labels,
        ylabel='Annotation',
        xlabel='Prediction',
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

    threshold = cm_norm.max() / 2.0
    for i in range(cm_norm.shape[0]):
        for j in range(cm_norm.shape[1]):
            value = cm_norm[i, j]
            ax.text(
                j,
                i,
                f'{value:.2f}',
                ha='center',
                va='center',
                color='white' if value > threshold else 'black',
                fontsize=9,
            )

    fig.tight_layout()
    plt.show()
    return cm_norm

cm_norm = draw_confusion_matrix_percent(cm, category_names)

# %% [markdown]
# ### Metricas

# %%
print(classification_report(y_true_idx, y_pred_idx, target_names=category_names, digits=4))
# Out:
#                     precision    recall  f1-score   support
#
#        Cargo plane     0.9438    0.8842    0.9130        95
#          Small car     0.6954    0.8737    0.7744       499
#                Bus     0.4444    0.5736    0.5008       265
#              Truck     0.3675    0.1837    0.2450       332
#          Motorboat     0.7329    0.6687    0.6993       160
#     Fishing vessel     0.7449    0.6887    0.7157       106
#         Dump truck     0.4770    0.4486    0.4624       185
#          Excavator     0.6129    0.6441    0.6281       118
#           Building     0.7053    0.8349    0.7647       539
#            Helipad     1.0000    0.1176    0.2105        17
#       Storage tank     0.6067    0.4136    0.4919       220
# Shipping container     0.6037    0.5721    0.5874       229
#              Pylon     0.8462    0.7021    0.7674        47
#
#           accuracy                         0.6326      2812
#          macro avg     0.6754    0.5851    0.5970      2812
#       weighted avg     0.6194    0.6326    0.6149      2812

# %% [markdown]
# ## Codabench

# %% [markdown]
# ### Generacion del submission

# %%
CODABENCH_START = time.perf_counter()

def load_test_image(filename):
    return np.array(Image.open(DATA_ROOT / filename).convert('RGB'))

test_files = sorted(TEST_DIR.rglob('*.tif'))
print('Number of testing images:', len(test_files))
assert len(test_files) > 0, 'No se encontraron imagenes .tif en TEST_DIR.'

model.load_weights(MODEL_PATH)
predictions_data = {'images': {}, 'annotations': {}}
batch_size = 64

for start in range(0, len(test_files), batch_size):
    batch_paths = test_files[start:start + batch_size]
    json_filenames = [path.relative_to(TEST_DIR).as_posix() for path in batch_paths]
    load_filenames = [path.relative_to(DATA_ROOT).as_posix() for path in batch_paths]

    images = np.stack([load_test_image(filename) for filename in load_filenames]).astype(np.uint8)
    probs = model.predict(images, batch_size=batch_size, verbose=0)
    pred_idx = np.argmax(probs, axis=1)
    pred_scores = np.max(probs, axis=1)

    for offset, (path, json_filename, cls_idx, score) in enumerate(zip(batch_paths, json_filenames, pred_idx, pred_scores)):
        idx = start + offset
        predictions_data['images'][idx] = {
            'image_id': path.name,
            'filename': json_filename,
            'width': 224,
            'height': 224,
        }
        predictions_data['annotations'][idx] = {
            'image_id': path.name,
            'category_id': category_names[int(cls_idx)],
            'score': float(score),
            'bbox': [0, 0, 224, 224],
        }

    print(f'Procesadas {min(start + batch_size, len(test_files))}/{len(test_files)}')

assert len(predictions_data['images']) == len(test_files)
assert len(predictions_data['annotations']) == len(test_files)

prediction_path = WORKDIR / 'prediction_08.json'
submission_path = WORKDIR / 'submission_08.zip'

with open(prediction_path, 'w', encoding='utf-8') as outfile:
    json.dump(predictions_data, outfile)

with zipfile.ZipFile(submission_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    zf.write(prediction_path, arcname='prediction.json')

CODABENCH_TIME = time.perf_counter() - CODABENCH_START

print('Archivos generados:')
print(prediction_path, '-', prediction_path.stat().st_size, 'bytes')
print(submission_path, '-', submission_path.stat().st_size, 'bytes')
print(f'Tiempo Codabench: {CODABENCH_TIME:.2f} s')

from IPython.display import FileLink, display
display(FileLink(str(submission_path)))
# Out:
# Number of testing images: 2365
# Procesadas 64/2365
# Procesadas 128/2365
# Procesadas 192/2365
# Procesadas 256/2365
# Procesadas 320/2365
# Procesadas 384/2365
# Procesadas 448/2365
# Procesadas 512/2365
# Procesadas 576/2365
# Procesadas 640/2365
# Procesadas 704/2365
# Procesadas 768/2365
# Procesadas 832/2365
# Procesadas 896/2365
# Procesadas 960/2365
# Procesadas 1024/2365
# Procesadas 1088/2365
# Procesadas 1152/2365
# Procesadas 1216/2365
# Procesadas 1280/2365
# Procesadas 1344/2365
# Procesadas 1408/2365
# Procesadas 1472/2365
# Procesadas 1536/2365
# Procesadas 1600/2365
# Procesadas 1664/2365
# Procesadas 1728/2365
# Procesadas 1792/2365
# Procesadas 1856/2365
# Procesadas 1920/2365
# Procesadas 1984/2365
# Procesadas 2048/2365
# Procesadas 2112/2365
# Procesadas 2176/2365
# Procesadas 2240/2365
# Procesadas 2304/2365
# Procesadas 2365/2365
# Archivos generados:
# /kaggle/working/prediction_08.json - 729729 bytes
# /kaggle/working/submission_08.zip - 165133 bytes
# Tiempo Codabench: 26.21 s
# /kaggle/working/submission_08.zip

# %% [markdown]
# ### Resumen de tiempos

# %%
TOTAL_TIME = time.perf_counter() - RUN_START
print('Resumen de tiempos')
if 'DATA_LOAD_TIME' in globals():
    print(f'- Carga/preparacion de datos: {DATA_LOAD_TIME:.2f} s')
if 'TRAIN_TIME' in globals():
    print(f'- Entrenamiento: {TRAIN_TIME:.2f} s')
if 'CODABENCH_TIME' in globals():
    print(f'- Codabench: {CODABENCH_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME / 60:.2f} min')
# Out:
# Resumen de tiempos
# - Carga/preparacion de datos: 1.92 s
# - Entrenamiento: 2526.71 s
# - Codabench: 26.21 s
# - Tiempo total Run All: 2574.05 s
# - Tiempo total Run All: 42.90 min
