# %% [markdown]
# # 03 - ffNN normalizada
#
# Modelo feed-forward sobre pixeles aplanados, igual que el `02_ffnn_simple`, pero normalizando los valores de pixel a `[0, 1]`. La diferencia principal es aislar el efecto de la normalizacion antes de anadir regularizacion o redes convolucionales.

# %% [markdown]
# ## Librerias y configuracion

# %%
import json
import math
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import rasterio
import warnings
from rasterio.errors import NotGeoreferencedWarning

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

print('GPUs disponibles:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-05-28 06:49:20.928187: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779950961.297538      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779950961.403095      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779950962.541031      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779950962.541073      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779950962.541075      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779950962.541078      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# Kaggle-only: busca automaticamente xview_ann_train.json dentro de /kaggle/input.
KAGGLE_INPUT_DIR = Path('/kaggle/input')

if not KAGGLE_INPUT_DIR.exists():
    raise FileNotFoundError(
        'No existe /kaggle/input. Ejecuta este notebook en Kaggle y anade el dataset xview_recognition como Input.'
    )

json_matches = sorted(KAGGLE_INPUT_DIR.rglob('xview_ann_train.json'))
if not json_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(
        'No se encontro xview_ann_train.json dentro de /kaggle/input. '
        f'Inputs disponibles: {available_inputs}. '
        'Comprueba que has anadido el dataset xview_recognition al notebook.'
    )

ANN_JSON = json_matches[0]
DATA_ROOT = ANN_JSON.parent
TRAIN_DIR = DATA_ROOT / 'xview_train'
TEST_DIR = DATA_ROOT / 'xview_test'
WORKDIR = Path('/kaggle/working')

print('DATA_ROOT:', DATA_ROOT)
print('ANN_JSON:', ANN_JSON)
print('TRAIN_DIR exists:', TRAIN_DIR.exists())
print('TEST_DIR exists:', TEST_DIR.exists())
# Out:
# DATA_ROOT: /kaggle/input/datasets/eccvdl/xview-recognition
# ANN_JSON: /kaggle/input/datasets/eccvdl/xview-recognition/xview_ann_train.json
# TRAIN_DIR exists: True
# TEST_DIR exists: True

# %% [markdown]
# ## Datos

# %% [markdown]
# ### Lectura del JSON

# %%
def load_geoimage(filename):
    warnings.filterwarnings('ignore', category=NotGeoreferencedWarning)
    with rasterio.open(DATA_ROOT / filename, 'r') as src_raster:
        img = np.zeros((src_raster.height, src_raster.width, src_raster.count), dtype=src_raster.profile['dtype'])
        for band in range(src_raster.count):
            img[:, :, band] = src_raster.read(band + 1)
    return img

# %%
with open(ANN_JSON, 'r', encoding='utf-8') as f:
    json_data = json.load(f)

categories = {
    int(k): v['name']
    for k, v in sorted(json_data['categories'].items(), key=lambda item: int(item[0]))
}
category_names = list(categories.values())
category_to_idx = {name: idx for idx, name in categories.items()}
num_classes = len(category_names)

print('Categorias:')
print(categories)
print('Imagenes en JSON:', len(json_data['images']))
print('Anotaciones en JSON:', len(json_data['annotations']))
# Out:
# Categorias:
# {0: 'Cargo plane', 1: 'Small car', 2: 'Bus', 3: 'Truck', 4: 'Motorboat', 5: 'Fishing vessel', 6: 'Dump truck', 7: 'Excavator', 8: 'Building', 9: 'Helipad', 10: 'Storage tank', 11: 'Shipping container', 12: 'Pylon'}
# Imagenes en JSON: 18746
# Anotaciones en JSON: 18746

# %%
rows = []
for json_img, json_ann in zip(json_data['images'].values(), json_data['annotations'].values()):
    rows.append({
        'image_id': json_img['image_id'],
        'filename': json_img['filename'],
        'width': json_img['width'],
        'height': json_img['height'],
        'category': json_ann['category_id'],
        'label': category_to_idx[json_ann['category_id']],
        'bbox': json_ann['bbox'],
        'exists': (DATA_ROOT / json_img['filename']).exists(),
    })

df = pd.DataFrame(rows)
print('Total train:', len(df))
print('Archivos encontrados:', int(df['exists'].sum()))
df.head()
# Out:
# Total train: 18746
# Archivos encontrados: 18746
#                                    image_id  \
# 0  0234476c-a017-4c9b-bd2f-872193076cca.tif
# 1  f2543073-9933-44c4-98e0-15eee2dffe2a.tif
# 2  6df5b6a5-82b0-4abb-8deb-7d7154c977bc.tif
# 3  ddbd2636-ce3c-4406-a5cf-92fa557dbd3c.tif
# 4  609064d1-3719-4163-ad36-577dab9805f0.tif
#
#                                             filename  width  height  category  \
# 0  xview_train/Building/0234476c-a017-4c9b-bd2f-8...    224     224  Building
# 1  xview_train/Building/f2543073-9933-44c4-98e0-1...    224     224  Building
# 2  xview_train/Building/6df5b6a5-82b0-4abb-8deb-7...    224     224  Building
# 3  xview_train/Building/ddbd2636-ce3c-4406-a5cf-9...    224     224  Building
# 4  xview_train/Building/609064d1-3719-4163-ad36-5...    224     224  Building
#
#    label              bbox  exists
# 0      8  [0, 0, 224, 224]    True
# 1      8  [0, 0, 224, 224]    True
# 2      8  [0, 0, 224, 224]    True
# 3      8  [0, 0, 224, 224]    True
# 4      8  [0, 0, 224, 224]    True

# %%
class_counts = df['category'].value_counts().reindex(category_names)
print('Distribucion por clase:')
print(class_counts)

plt.figure(figsize=(12, 5))
plt.bar(class_counts.index, class_counts.values)
plt.xticks(rotation=45, ha='right')
plt.ylabel('Numero de imagenes')
plt.title('Distribucion de clases')
plt.tight_layout()
plt.show()
# Out:
# Distribucion por clase:
# category
# Cargo plane            635
# Small car             3324
# Bus                   1768
# Truck                 2210
# Motorboat             1069
# Fishing vessel         706
# Dump truck            1236
# Excavator              789
# Building              3594
# Helipad                111
# Storage tank          1469
# Shipping container    1523
# Pylon                  312
# Name: count, dtype: int64

# %% [markdown]
# ### Comprobacion de una imagen

# %%
sample_row = df.iloc[0]
sample_img = load_geoimage(sample_row['filename'])

print('Filename:', sample_row['filename'])
print('Shape:', sample_img.shape)
print('Dtype:', sample_img.dtype)
print('Min / Max:', sample_img.min(), sample_img.max())
print('Etiqueta:', sample_row['category'])
print('Indice de clase:', sample_row['label'])
print('Bounding box:', sample_row['bbox'])
print('Primeros pixeles del array:')
print(sample_img[:3, :3, :])

plt.figure(figsize=(4, 4))
plt.imshow(sample_img)
plt.title(sample_row['category'])
plt.axis('off')
plt.show()
# Out:
# Filename: xview_train/Building/0234476c-a017-4c9b-bd2f-872193076cca.tif
# Shape: (224, 224, 3)
# Dtype: uint8
# Min / Max: 0 86
# Etiqueta: Building
# Indice de clase: 8
# Bounding box: [0, 0, 224, 224]
# Primeros pixeles del array:
# [[[45 30 19]
#   [45 30 19]
#   [46 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]]

# %% [markdown]
# ### Split train/valid

# %%
train_df, val_df = train_test_split(
    df,
    test_size=0.15,
    random_state=42,
    shuffle=True,
    stratify=df['label'],
)

print('Train:', len(train_df))
print('Validation:', len(val_df))

split_counts = pd.concat([
    train_df['category'].value_counts().reindex(category_names).rename('train'),
    val_df['category'].value_counts().reindex(category_names).rename('valid'),
], axis=1)
split_counts
# Out:
# Train: 15934
# Validation: 2812
#                     train  valid
# category
# Cargo plane           540     95
# Small car            2825    499
# Bus                  1503    265
# Truck                1878    332
# Motorboat             909    160
# Fishing vessel        600    106
# Dump truck           1051    185
# Excavator             671    118
# Building             3055    539
# Helipad                94     17
# Storage tank         1249    220
# Shipping container   1294    229
# Pylon                 265     47

# %% [markdown]
# ## Red

# %% [markdown]
# ### Arquitectura y summary

# %%
def normalize_01(images):
    return images / 255.0

class XViewSequence(tf.keras.utils.Sequence):
    def __init__(self, data, batch_size=32, shuffle=False):
        self.data = data.reset_index(drop=True)
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.indexes = np.arange(len(self.data))
        self.on_epoch_end()

    def __len__(self):
        return math.ceil(len(self.data) / self.batch_size)

    def on_epoch_end(self):
        if self.shuffle:
            np.random.shuffle(self.indexes)

    def __getitem__(self, idx):
        batch_idx = self.indexes[idx * self.batch_size:(idx + 1) * self.batch_size]
        batch = self.data.iloc[batch_idx]
        images = np.stack([load_geoimage(filename) for filename in batch['filename']]).astype(np.float32)
        images = normalize_01(images)
        images = images.reshape((images.shape[0], -1))
        labels = tf.keras.utils.to_categorical(batch['label'].to_numpy(), num_classes=num_classes)
        return images, labels

# %%
BATCH_SIZE = 64
EPOCHS = 30

train_seq = XViewSequence(train_df, batch_size=BATCH_SIZE, shuffle=True)
val_seq = XViewSequence(val_df, batch_size=BATCH_SIZE, shuffle=False)

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(224 * 224 * 3,)),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(num_classes, activation='softmax'),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=3e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model.summary()
# Out:
# I0000 00:00:1779951036.496495      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1779951036.502687      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │    38,535,424 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 13)             │         1,677 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 38,569,997 (147.13 MB)
#  Trainable params: 38,569,997 (147.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Callbacks

# %%
MODEL_PATH = WORKDIR / '03_ffnn_normalizada.keras'
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(str(MODEL_PATH), monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-7, verbose=1),
    tf.keras.callbacks.TerminateOnNaN(),
]

print('Modelo guardado en:', MODEL_PATH)
# Out:
# Modelo guardado en: /kaggle/working/03_ffnn_normalizada.keras

# %% [markdown]
# ### Entrenamiento

# %%
history = model.fit(
    train_seq,
    validation_data=val_seq,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

best_idx = int(np.argmax(history.history['val_accuracy']))
best_value = float(np.max(history.history['val_accuracy']))
print('Best validation model: epoch', best_idx + 1, '- val_accuracy', best_value)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779951051.628961     131 service.cc:152] XLA service 0x7c4b14004840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779951051.629000     131 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779951051.629005     131 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1779951052.630634     131 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   1/249 ━━━━━━━━━━━━━━━━━━━━ 33:11 8s/step - accuracy: 0.0312 - loss: 2.7243
# I0000 00:00:1779951054.261186     131 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2505 - loss: 4.1008
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1: val_accuracy improved from None to 0.31863, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 1: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 1190s 5s/step - accuracy: 0.3063 - loss: 2.6623 - val_accuracy: 0.3186 - val_loss: 2.0035 - learning_rate: 3.0000e-04
# Epoch 2/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.3633 - loss: 1.9641
# Epoch 2: val_accuracy improved from 0.31863 to 0.39296, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 2: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 116s 464ms/step - accuracy: 0.3840 - loss: 1.8881 - val_accuracy: 0.3930 - val_loss: 1.7570 - learning_rate: 3.0000e-04
# Epoch 3/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.4190 - loss: 1.7675
# Epoch 3: val_accuracy improved from 0.39296 to 0.44879, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 3: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 103s 412ms/step - accuracy: 0.4122 - loss: 1.7756 - val_accuracy: 0.4488 - val_loss: 1.7287 - learning_rate: 3.0000e-04
# Epoch 4/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.4223 - loss: 1.7441
# Epoch 4: val_accuracy did not improve from 0.44879
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 407ms/step - accuracy: 0.4266 - loss: 1.7176 - val_accuracy: 0.4452 - val_loss: 1.6519 - learning_rate: 3.0000e-04
# Epoch 5/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.4470 - loss: 1.6236
# Epoch 5: val_accuracy did not improve from 0.44879
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 408ms/step - accuracy: 0.4485 - loss: 1.6348 - val_accuracy: 0.4015 - val_loss: 1.8811 - learning_rate: 3.0000e-04
# Epoch 6/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.4425 - loss: 1.6585
# Epoch 6: val_accuracy did not improve from 0.44879
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 404ms/step - accuracy: 0.4544 - loss: 1.6290 - val_accuracy: 0.4267 - val_loss: 1.6713 - learning_rate: 3.0000e-04
# Epoch 7/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 0.4714 - loss: 1.5661
# Epoch 7: val_accuracy improved from 0.44879 to 0.47368, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 7: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 104s 419ms/step - accuracy: 0.4656 - loss: 1.5821 - val_accuracy: 0.4737 - val_loss: 1.5778 - learning_rate: 3.0000e-04
# Epoch 8/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.4872 - loss: 1.5071
# Epoch 8: val_accuracy did not improve from 0.47368
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 103s 413ms/step - accuracy: 0.4783 - loss: 1.5369 - val_accuracy: 0.4726 - val_loss: 1.5973 - learning_rate: 3.0000e-04
# Epoch 9/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.4858 - loss: 1.5089
# Epoch 9: val_accuracy improved from 0.47368 to 0.47688, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 9: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 107s 430ms/step - accuracy: 0.4857 - loss: 1.5149 - val_accuracy: 0.4769 - val_loss: 1.6325 - learning_rate: 3.0000e-04
# Epoch 10/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.4934 - loss: 1.4937
# Epoch 10: val_accuracy did not improve from 0.47688
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 102s 411ms/step - accuracy: 0.4913 - loss: 1.4923 - val_accuracy: 0.4691 - val_loss: 1.6513 - learning_rate: 3.0000e-04
# Epoch 11/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step - accuracy: 0.5390 - loss: 1.3677
# Epoch 11: val_accuracy improved from 0.47688 to 0.50996, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 11: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 106s 424ms/step - accuracy: 0.5432 - loss: 1.3588 - val_accuracy: 0.5100 - val_loss: 1.4906 - learning_rate: 9.0000e-05
# Epoch 12/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5456 - loss: 1.3362
# Epoch 12: val_accuracy did not improve from 0.50996
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 406ms/step - accuracy: 0.5436 - loss: 1.3443 - val_accuracy: 0.5096 - val_loss: 1.4969 - learning_rate: 9.0000e-05
# Epoch 13/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5452 - loss: 1.3348
# Epoch 13: val_accuracy did not improve from 0.50996
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 100s 401ms/step - accuracy: 0.5509 - loss: 1.3317 - val_accuracy: 0.5053 - val_loss: 1.5233 - learning_rate: 9.0000e-05
# Epoch 14/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5513 - loss: 1.3192
# Epoch 14: val_accuracy improved from 0.50996 to 0.51316, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 14: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 104s 416ms/step - accuracy: 0.5519 - loss: 1.3303 - val_accuracy: 0.5132 - val_loss: 1.5171 - learning_rate: 9.0000e-05
# Epoch 15/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5797 - loss: 1.2717
# Epoch 15: val_accuracy improved from 0.51316 to 0.51956, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 15: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 102s 410ms/step - accuracy: 0.5732 - loss: 1.2736 - val_accuracy: 0.5196 - val_loss: 1.4715 - learning_rate: 2.7000e-05
# Epoch 16/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.5749 - loss: 1.2735
# Epoch 16: val_accuracy improved from 0.51956 to 0.52134, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 16: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 103s 412ms/step - accuracy: 0.5756 - loss: 1.2682 - val_accuracy: 0.5213 - val_loss: 1.4768 - learning_rate: 2.7000e-05
# Epoch 17/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 347ms/step - accuracy: 0.5837 - loss: 1.2509
# Epoch 17: val_accuracy improved from 0.52134 to 0.52418, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 17: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 104s 416ms/step - accuracy: 0.5780 - loss: 1.2655 - val_accuracy: 0.5242 - val_loss: 1.4653 - learning_rate: 2.7000e-05
# Epoch 18/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5769 - loss: 1.2503
# Epoch 18: val_accuracy improved from 0.52418 to 0.52632, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 18: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 103s 415ms/step - accuracy: 0.5752 - loss: 1.2606 - val_accuracy: 0.5263 - val_loss: 1.4730 - learning_rate: 2.7000e-05
# Epoch 19/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step - accuracy: 0.5809 - loss: 1.2499
# Epoch 19: val_accuracy did not improve from 0.52632
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 100s 404ms/step - accuracy: 0.5771 - loss: 1.2577 - val_accuracy: 0.5235 - val_loss: 1.4723 - learning_rate: 2.7000e-05
# Epoch 20/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step - accuracy: 0.5826 - loss: 1.2466
# Epoch 20: val_accuracy did not improve from 0.52632
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 99s 397ms/step - accuracy: 0.5779 - loss: 1.2543 - val_accuracy: 0.5217 - val_loss: 1.4724 - learning_rate: 2.7000e-05
# Epoch 21/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.5916 - loss: 1.2279
# Epoch 21: val_accuracy improved from 0.52632 to 0.53129, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 21: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 106s 425ms/step - accuracy: 0.5896 - loss: 1.2333 - val_accuracy: 0.5313 - val_loss: 1.4559 - learning_rate: 8.1000e-06
# Epoch 22/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.5912 - loss: 1.2286
# Epoch 22: val_accuracy improved from 0.53129 to 0.53201, saving model to /kaggle/working/03_ffnn_normalizada.keras
#
# Epoch 22: finished saving model to /kaggle/working/03_ffnn_normalizada.keras
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 105s 423ms/step - accuracy: 0.5902 - loss: 1.2315 - val_accuracy: 0.5320 - val_loss: 1.4588 - learning_rate: 8.1000e-06
# Epoch 23/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5872 - loss: 1.2287
# Epoch 23: val_accuracy did not improve from 0.53201
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 405ms/step - accuracy: 0.5887 - loss: 1.2297 - val_accuracy: 0.5210 - val_loss: 1.4704 - learning_rate: 8.1000e-06
# Epoch 24/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step - accuracy: 0.5872 - loss: 1.2243
# Epoch 24: val_accuracy did not improve from 0.53201
#
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 407ms/step - accuracy: 0.5906 - loss: 1.2280 - val_accuracy: 0.5263 - val_loss: 1.4609 - learning_rate: 8.1000e-06
# Epoch 25/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step - accuracy: 0.5915 - loss: 1.2173
# Epoch 25: val_accuracy did not improve from 0.53201
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 101s 407ms/step - accuracy: 0.5950 - loss: 1.2215 - val_accuracy: 0.5277 - val_loss: 1.4586 - learning_rate: 2.4300e-06
# Epoch 26/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.5994 - loss: 1.2099
# Epoch 26: val_accuracy did not improve from 0.53201
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 100s 401ms/step - accuracy: 0.5934 - loss: 1.2206 - val_accuracy: 0.5274 - val_loss: 1.4589 - learning_rate: 2.4300e-06
# Epoch 27/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step - accuracy: 0.5928 - loss: 1.2178
# Epoch 27: val_accuracy did not improve from 0.53201
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 7.289999985005124e-07.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 100s 402ms/step - accuracy: 0.5933 - loss: 1.2201 - val_accuracy: 0.5277 - val_loss: 1.4588 - learning_rate: 2.4300e-06
# Epoch 28/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.6004 - loss: 1.2047
# Epoch 28: val_accuracy did not improve from 0.53201
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 100s 400ms/step - accuracy: 0.5946 - loss: 1.2180 - val_accuracy: 0.5284 - val_loss: 1.4579 - learning_rate: 7.2900e-07
# Epoch 29/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5952 - loss: 1.2171
# Epoch 29: val_accuracy did not improve from 0.53201
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 99s 399ms/step - accuracy: 0.5960 - loss: 1.2175 - val_accuracy: 0.5284 - val_loss: 1.4582 - learning_rate: 7.2900e-07
# Epoch 30/30
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step - accuracy: 0.5939 - loss: 1.2141
# Epoch 30: val_accuracy did not improve from 0.53201
#
# Epoch 30: ReduceLROnPlateau reducing learning rate to 2.1870000637136398e-07.
# 249/249 ━━━━━━━━━━━━━━━━━━━━ 99s 399ms/step - accuracy: 0.5948 - loss: 1.2173 - val_accuracy: 0.5274 - val_loss: 1.4580 - learning_rate: 7.2900e-07
# Restoring model weights from the end of the best epoch: 22.
# Best validation model: epoch 22 - val_accuracy 0.5320056676864624

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### Graficas de entrenamiento

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Matriz de confusion

# %%
model.load_weights(MODEL_PATH)
probs = model.predict(val_seq, verbose=1)
y_pred_idx = np.argmax(probs, axis=1)
y_true_idx = val_df['label'].to_numpy()

cm = confusion_matrix(y_true_idx, y_pred_idx, labels=list(range(num_classes)))
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 15s 343ms/step

# %%
def draw_confusion_matrix_percent(cm, labels):
    cm_norm = cm.astype(float) / np.maximum(cm.sum(axis=1, keepdims=True), np.finfo(np.float64).eps)

    fig, ax = plt.subplots(figsize=(14, 12))
    im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.colormaps['Blues'], vmin=0.0, vmax=max(0.01, cm_norm.max()))
    fig.colorbar(im, ax=ax)

    ax.set(
        xticks=np.arange(len(labels)),
        yticks=np.arange(len(labels)),
        xticklabels=labels,
        yticklabels=labels,
        ylabel='Annotation',
        xlabel='Prediction',
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

    threshold = cm_norm.max() / 2.0
    for i in range(cm_norm.shape[0]):
        for j in range(cm_norm.shape[1]):
            value = cm_norm[i, j]
            ax.text(
                j,
                i,
                f'{value:.2f}',
                ha='center',
                va='center',
                color='white' if value > threshold else 'black',
                fontsize=9,
            )

    ax.set_title('Matriz de confusion normalizada por clase real')
    fig.tight_layout()
    plt.show()

draw_confusion_matrix_percent(cm, category_names)

# %% [markdown]
# ### Metricas por clase

# %%
correct = np.diag(cm).astype(float)
total_true = np.sum(cm, axis=1).astype(float)
total_pred = np.sum(cm, axis=0).astype(float)

print('Mean Accuracy: %.3f%%' % (np.sum(correct) / np.sum(total_true) * 100))
print('Mean Recall: %.3f%%' % ((correct / np.maximum(total_true, np.finfo(np.float64).eps)).mean() * 100))
print('Mean Precision: %.3f%%' % ((correct / np.maximum(total_pred, np.finfo(np.float64).eps)).mean() * 100))

for idx, name in enumerate(category_names):
    tp = cm[idx, idx]
    fp = sum(cm[:, idx]) - tp
    fn = sum(cm[idx, :]) - tp
    tn = sum(np.delete(sum(cm) - cm[idx, :], idx))
    recall = tp / np.maximum(tp + fn, np.finfo(np.float64).eps)
    precision = tp / np.maximum(tp + fp, np.finfo(np.float64).eps)
    specificity = tn / np.maximum(tn + fp, np.finfo(np.float64).eps)
    f1_score = 2 * ((precision * recall) / np.maximum(precision + recall, np.finfo(np.float64).eps))
    print('> %s: Recall: %.3f%% Precision: %.3f%% Specificity: %.3f%% Dice: %.3f%%' % (name, recall * 100, precision * 100, specificity * 100, f1_score * 100))
# Out:
# Mean Accuracy: 53.201%
# Mean Recall: 43.815%
# Mean Precision: 46.787%
# > Cargo plane: Recall: 72.632% Precision: 66.990% Specificity: 98.749% Dice: 69.697%
# > Small car: Recall: 88.176% Precision: 66.165% Specificity: 90.272% Dice: 75.601%
# > Bus: Recall: 40.755% Precision: 42.520% Specificity: 94.268% Dice: 41.618%
# > Truck: Recall: 14.157% Precision: 22.596% Specificity: 93.508% Dice: 17.407%
# > Motorboat: Recall: 35.000% Precision: 43.750% Specificity: 97.285% Dice: 38.889%
# > Fishing vessel: Recall: 17.925% Precision: 46.341% Specificity: 99.187% Dice: 25.850%
# > Dump truck: Recall: 42.703% Precision: 50.641% Specificity: 97.069% Dice: 46.334%
# > Excavator: Recall: 45.763% Precision: 54.000% Specificity: 98.293% Dice: 49.541%
# > Building: Recall: 76.438% Precision: 57.462% Specificity: 86.582% Dice: 65.605%
# > Helipad: Recall: 0.000% Precision: 0.000% Specificity: 99.964% Dice: 0.000%
# > Storage tank: Recall: 30.455% Precision: 56.303% Specificity: 97.994% Dice: 39.528%
# > Shipping container: Recall: 52.402% Precision: 43.321% Specificity: 93.922% Dice: 47.431%
# > Pylon: Recall: 53.191% Precision: 58.140% Specificity: 99.349% Dice: 55.556%

# %% [markdown]
# ## Codabench
#
# El conjunto test no tiene etiquetas publicas. Esta seccion recorre `xview_test`, genera `prediction.json` y lo comprime como `submission.zip` para Codabench.

# %%
test_files = sorted(TEST_DIR.rglob('*.tif'))
print('Number of testing images:', len(test_files))
# Out:
# Number of testing images: 2365

# %%
model.load_weights(MODEL_PATH)
predictions_data = {'images': {}, 'annotations': {}}
batch_size = 64

for start in range(0, len(test_files), batch_size):
    batch_paths = test_files[start:start + batch_size]

    # Ruta que queremos guardar en el JSON
    json_filenames = [path.relative_to(TEST_DIR).as_posix() for path in batch_paths]

    # Ruta que necesita load_geoimage para abrir la imagen desde DATA_ROOT
    load_filenames = [path.relative_to(DATA_ROOT).as_posix() for path in batch_paths]

    images = np.stack([load_geoimage(filename) for filename in load_filenames]).astype(np.float32)
    images = normalize_01(images)
    images = images.reshape((images.shape[0], -1))

    probs = model.predict(images, verbose=0)
    pred_idx = np.argmax(probs, axis=1)
    pred_scores = np.max(probs, axis=1)

    for offset, (path, json_filename, cls_idx, score) in enumerate(
        zip(batch_paths, json_filenames, pred_idx, pred_scores)
    ):
        idx = start + offset

        predictions_data['images'][idx] = {
            'image_id': path.name,
            'filename': json_filename,
            'width': 224,
            'height': 224,
        }

        predictions_data['annotations'][idx] = {
            'image_id': path.name,
            'category_id': category_names[int(cls_idx)],
            'score': float(score),
            'bbox': [0, 0, 224, 224],
        }

    print(f'Procesadas {min(start + batch_size, len(test_files))}/{len(test_files)}')

assert len(predictions_data['images']) == len(test_files)
assert len(predictions_data['annotations']) == len(test_files)

prediction_path = WORKDIR / 'prediction_03.json'
submission_path = WORKDIR / 'submission_03.zip'

with open(prediction_path, 'w', encoding='utf-8') as outfile:
    json.dump(predictions_data, outfile)

with zipfile.ZipFile(submission_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    zf.write(prediction_path, arcname='prediction.json')

print('Archivos generados:')
print(prediction_path, '-', prediction_path.stat().st_size, 'bytes')
print(submission_path, '-', submission_path.stat().st_size, 'bytes')

from IPython.display import FileLink, display
display(FileLink(str(submission_path)))
# Out:
# Procesadas 64/2365
# Procesadas 128/2365
# Procesadas 192/2365
# Procesadas 256/2365
# Procesadas 320/2365
# Procesadas 384/2365
# Procesadas 448/2365
# Procesadas 512/2365
# Procesadas 576/2365
# Procesadas 640/2365
# Procesadas 704/2365
# Procesadas 768/2365
# Procesadas 832/2365
# Procesadas 896/2365
# Procesadas 960/2365
# Procesadas 1024/2365
# Procesadas 1088/2365
# Procesadas 1152/2365
# Procesadas 1216/2365
# Procesadas 1280/2365
# Procesadas 1344/2365
# Procesadas 1408/2365
# Procesadas 1472/2365
# Procesadas 1536/2365
# Procesadas 1600/2365
# Procesadas 1664/2365
# Procesadas 1728/2365
# Procesadas 1792/2365
# Procesadas 1856/2365
# Procesadas 1920/2365
# Procesadas 1984/2365
# Procesadas 2048/2365
# Procesadas 2112/2365
# Procesadas 2176/2365
# Procesadas 2240/2365
# Procesadas 2304/2365
# Procesadas 2365/2365
# Archivos generados:
# /kaggle/working/prediction_03.json - 730009 bytes
# /kaggle/working/submission_03.zip - 165669 bytes
# /kaggle/working/submission_03.zip
