# %% [markdown]
# # 07 - CNN regularizada usando arrays
#
# CNN con BatchNormalization, Dropout y regularizacion L2 que usa el dataset preprocesado de arrays (`X_all.npy`) para evitar leer miles de `.tif` durante el entrenamiento.

# %% [markdown]
# ## Librerias y configuracion

# %%
import json
import time
import zipfile
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from PIL import Image

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

RUN_START = time.perf_counter()

print('GPUs disponibles:', tf.config.list_physical_devices('GPU'))
# Out:
# 2026-06-01 17:59:46.336428: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780336786.528298      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780336786.585416      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780336787.047403      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780336787.047441      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780336787.047445      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780336787.047447      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# GPUs disponibles: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
SEED = 42
BATCH_SIZE = 32
EPOCHS = 40
VALIDATION_SIZE = 0.15
IMAGE_SHAPE = (224, 224, 3)

np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Datos

# %% [markdown]
# ### Localizacion de inputs

# %%
KAGGLE_INPUT_DIR = Path('/kaggle/input')
WORKDIR = Path('/kaggle/working')

if not KAGGLE_INPUT_DIR.exists():
    raise FileNotFoundError('No existe /kaggle/input. Ejecuta este notebook en Kaggle.')

array_matches = sorted(KAGGLE_INPUT_DIR.rglob('X_all.npy'))
working_candidate = WORKDIR / 'xview_arrays' / 'X_all.npy'
if working_candidate.exists():
    array_matches = [working_candidate] + array_matches

if not array_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(
        'No se encontro X_all.npy. Anade el dataset xview_arrays creado con 00_1. '
        f'Inputs disponibles: {available_inputs}'
    )

ARRAYS_ROOT = array_matches[0].parent

json_matches = sorted(KAGGLE_INPUT_DIR.rglob('xview_ann_train.json'))
if not json_matches:
    available_inputs = [p.name for p in KAGGLE_INPUT_DIR.iterdir() if p.is_dir()]
    raise FileNotFoundError(
        'No se encontro xview_ann_train.json. Anade tambien el dataset original xview_recognition. '
        f'Inputs disponibles: {available_inputs}'
    )

ANN_JSON = json_matches[0]
DATA_ROOT = ANN_JSON.parent
TRAIN_DIR = DATA_ROOT / 'xview_train'
TEST_DIR = DATA_ROOT / 'xview_test'

print('ARRAYS_ROOT:', ARRAYS_ROOT)
print('DATA_ROOT:', DATA_ROOT)
print('ANN_JSON:', ANN_JSON)
print('TRAIN_DIR exists:', TRAIN_DIR.exists())
print('TEST_DIR exists:', TEST_DIR.exists())
# Out:
# ARRAYS_ROOT: /kaggle/input/datasets/eccvdl/xview-arrays/xview_arrays
# DATA_ROOT: /kaggle/input/datasets/eccvdl/xview-recognition
# ANN_JSON: /kaggle/input/datasets/eccvdl/xview-recognition/xview_ann_train.json
# TRAIN_DIR exists: True
# TEST_DIR exists: True

# %% [markdown]
# ### Lectura de arrays

# %%
DATA_LOAD_START = time.perf_counter()

X_all = np.load(ARRAYS_ROOT / 'X_all.npy')
y_all_idx = np.load(ARRAYS_ROOT / 'y_all_idx.npy')
filenames = np.load(ARRAYS_ROOT / 'filenames.npy')
image_ids = np.load(ARRAYS_ROOT / 'image_ids.npy')
category_names = np.load(ARRAYS_ROOT / 'category_names.npy').astype(str).tolist()
num_classes = len(category_names)

print('X_all:', X_all.shape, X_all.dtype, 'RAM aprox:', X_all.nbytes / 1024**3, 'GB')
print('y_all_idx:', y_all_idx.shape, y_all_idx.dtype)
print('filenames:', filenames.shape)
print('image_ids:', image_ids.shape)
print('num_classes:', num_classes)
print(category_names)
# Out:
# X_all: (18746, 224, 224, 3) uint8 RAM aprox: 2.6280040740966797 GB
# y_all_idx: (18746,) int32
# filenames: (18746,)
# image_ids: (18746,)
# num_classes: 13
# ['Cargo plane', 'Small car', 'Bus', 'Truck', 'Motorboat', 'Fishing vessel', 'Dump truck', 'Excavator', 'Building', 'Helipad', 'Storage tank', 'Shipping container', 'Pylon']

# %% [markdown]
# ### Comprobacion de una imagen

# %%
sample_idx = 0
sample_img = X_all[sample_idx]
sample_label_idx = int(y_all_idx[sample_idx])

print('Filename:', filenames[sample_idx])
print('Image id:', image_ids[sample_idx])
print('Shape:', sample_img.shape)
print('Dtype:', sample_img.dtype)
print('Min / Max:', sample_img.min(), sample_img.max())
print('Etiqueta:', category_names[sample_label_idx])
print('Primeros pixeles del array original:')
print(sample_img[:3, :3, :])
print('Primeros pixeles normalizados:')
print((sample_img.astype(np.float32) / 255.0)[:3, :3, :])

plt.figure(figsize=(4, 4))
plt.imshow(sample_img)
plt.title(category_names[sample_label_idx])
plt.axis('off')
plt.show()
# Out:
# Filename: xview_train/Building/0234476c-a017-4c9b-bd2f-872193076cca.tif
# Image id: 0234476c-a017-4c9b-bd2f-872193076cca.tif
# Shape: (224, 224, 3)
# Dtype: uint8
# Min / Max: 0 86
# Etiqueta: Building
# Primeros pixeles del array original:
# [[[45 30 19]
#   [45 30 19]
#   [46 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]
#
#  [[45 30 19]
#   [45 30 19]
#   [45 30 19]]]
# Primeros pixeles normalizados:
# [[[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.18039216 0.11764706 0.07450981]]
#
#  [[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]]
#
#  [[0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]
#   [0.1764706  0.11764706 0.07450981]]]

# %% [markdown]
# ### Split train/valid

# %%
indices = np.arange(len(X_all))
train_idx, val_idx = train_test_split(
    indices,
    test_size=VALIDATION_SIZE,
    random_state=SEED,
    shuffle=True,
    stratify=y_all_idx,
)

X_train = X_all[train_idx]
X_valid = X_all[val_idx]
y_train_idx = y_all_idx[train_idx]
y_valid_idx = y_all_idx[val_idx]

y_train = tf.keras.utils.to_categorical(y_train_idx, num_classes=num_classes).astype(np.float32)
y_valid = tf.keras.utils.to_categorical(y_valid_idx, num_classes=num_classes).astype(np.float32)

DATA_LOAD_TIME = time.perf_counter() - DATA_LOAD_START

print('X_train:', X_train.shape, X_train.dtype, 'RAM aprox:', X_train.nbytes / 1024**3, 'GB')
print('X_valid:', X_valid.shape, X_valid.dtype, 'RAM aprox:', X_valid.nbytes / 1024**3, 'GB')
print('y_train:', y_train.shape, y_train.dtype)
print('y_valid:', y_valid.shape, y_valid.dtype)
print(f'Tiempo carga arrays/split: {DATA_LOAD_TIME:.2f} s')
# Out:
# X_train: (15934, 224, 224, 3) uint8 RAM aprox: 2.2337894439697266 GB
# X_valid: (2812, 224, 224, 3) uint8 RAM aprox: 0.3942146301269531 GB
# y_train: (15934, 13) float32
# y_valid: (2812, 13) float32
# Tiempo carga arrays/split: 20.91 s

# %% [markdown]
# ## Red

# %% [markdown]
# ### Modelo

# %%
L2 = 1e-4

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=IMAGE_SHAPE),
    tf.keras.layers.Rescaling(1.0 / 255.0),

    tf.keras.layers.Conv2D(32, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(64, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(128, 3, padding='same', use_bias=False, kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation('relu'),
    tf.keras.layers.MaxPooling2D(),

    tf.keras.layers.Conv2D(256, 3, padding='same', activation='relu', kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dropout(0.4),
    tf.keras.layers.Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(L2)),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax'),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(5e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy'],
)

model.summary()
# Out:
# I0000 00:00:1780336839.286190      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1780336839.292372      58 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ rescaling (Rescaling)           │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 224, 224, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 64)   │        18,432 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 56, 56, 128)    │        73,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 13)             │         3,341 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 458,221 (1.75 MB)
#  Trainable params: 457,773 (1.75 MB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
# ### Callbacks

# %%
MODEL_PATH = WORKDIR / '07_cnn_regularizada_arrays.keras'

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(str(MODEL_PATH), monitor='val_accuracy', save_best_only=True, verbose=1),
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1),
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=3, min_lr=1e-7, verbose=1),
    tf.keras.callbacks.TerminateOnNaN(),
]

# %% [markdown]
# ### Entrenamiento

# %%
TRAIN_START = time.perf_counter()

history = model.fit(
    X_train,
    y_train,
    validation_data=(X_valid, y_valid),
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    callbacks=callbacks,
    verbose=1,
)

TRAIN_TIME = time.perf_counter() - TRAIN_START

best_idx = int(np.argmax(history.history['val_accuracy']))
best_value = float(np.max(history.history['val_accuracy']))
print('Best validation model: epoch', best_idx + 1, '- val_accuracy', best_value)
print(f'Tiempo entrenamiento: {TRAIN_TIME:.2f} s')
# Out:
# Epoch 1/40
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780336849.296312     129 service.cc:152] XLA service 0x790624049da0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780336849.296372     129 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780336849.296381     129 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1780336849.877205     129 cuda_dnn.cc:529] Loaded cuDNN version 91002
#   2/498 ━━━━━━━━━━━━━━━━━━━━ 41s 84ms/step - accuracy: 0.1094 - loss: 2.5986
# I0000 00:00:1780336857.532224     129 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.2621 - loss: 2.1977
# Epoch 1: val_accuracy improved from None to 0.32504, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 1: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 53s 85ms/step - accuracy: 0.3113 - loss: 2.0497 - val_accuracy: 0.3250 - val_loss: 2.0878 - learning_rate: 5.0000e-04
# Epoch 2/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.3888 - loss: 1.8308
# Epoch 2: val_accuracy improved from 0.32504 to 0.47617, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 2: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 32s 64ms/step - accuracy: 0.4075 - loss: 1.7759 - val_accuracy: 0.4762 - val_loss: 1.6101 - learning_rate: 5.0000e-04
# Epoch 3/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4364 - loss: 1.6838
# Epoch 3: val_accuracy improved from 0.47617 to 0.51849, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 3: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.4458 - loss: 1.6567 - val_accuracy: 0.5185 - val_loss: 1.5307 - learning_rate: 5.0000e-04
# Epoch 4/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4626 - loss: 1.6000
# Epoch 4: val_accuracy improved from 0.51849 to 0.52098, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 4: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 67ms/step - accuracy: 0.4731 - loss: 1.5791 - val_accuracy: 0.5210 - val_loss: 1.4778 - learning_rate: 5.0000e-04
# Epoch 5/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4896 - loss: 1.5532
# Epoch 5: val_accuracy improved from 0.52098 to 0.53983, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 5: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.4918 - loss: 1.5366 - val_accuracy: 0.5398 - val_loss: 1.4184 - learning_rate: 5.0000e-04
# Epoch 6/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5014 - loss: 1.5073
# Epoch 6: val_accuracy did not improve from 0.53983
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5097 - loss: 1.4850 - val_accuracy: 0.5381 - val_loss: 1.4147 - learning_rate: 5.0000e-04
# Epoch 7/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5109 - loss: 1.4657
# Epoch 7: val_accuracy improved from 0.53983 to 0.54765, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 7: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5210 - loss: 1.4479 - val_accuracy: 0.5477 - val_loss: 1.4007 - learning_rate: 5.0000e-04
# Epoch 8/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5310 - loss: 1.4312
# Epoch 8: val_accuracy did not improve from 0.54765
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5353 - loss: 1.4146 - val_accuracy: 0.5452 - val_loss: 1.4106 - learning_rate: 5.0000e-04
# Epoch 9/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5331 - loss: 1.4032
# Epoch 9: val_accuracy improved from 0.54765 to 0.58215, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 9: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5427 - loss: 1.3892 - val_accuracy: 0.5821 - val_loss: 1.2887 - learning_rate: 5.0000e-04
# Epoch 10/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5501 - loss: 1.3737
# Epoch 10: val_accuracy did not improve from 0.58215
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.5536 - loss: 1.3614 - val_accuracy: 0.5807 - val_loss: 1.3009 - learning_rate: 5.0000e-04
# Epoch 11/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5582 - loss: 1.3553
# Epoch 11: val_accuracy improved from 0.58215 to 0.59175, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 11: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5617 - loss: 1.3399 - val_accuracy: 0.5917 - val_loss: 1.2771 - learning_rate: 5.0000e-04
# Epoch 12/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5619 - loss: 1.3394
# Epoch 12: val_accuracy improved from 0.59175 to 0.60740, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 12: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5648 - loss: 1.3270 - val_accuracy: 0.6074 - val_loss: 1.2551 - learning_rate: 5.0000e-04
# Epoch 13/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5710 - loss: 1.3161
# Epoch 13: val_accuracy did not improve from 0.60740
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.5741 - loss: 1.3035 - val_accuracy: 0.6024 - val_loss: 1.2419 - learning_rate: 5.0000e-04
# Epoch 14/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5707 - loss: 1.3168
# Epoch 14: val_accuracy improved from 0.60740 to 0.60917, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 14: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5752 - loss: 1.3004 - val_accuracy: 0.6092 - val_loss: 1.2204 - learning_rate: 5.0000e-04
# Epoch 15/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5786 - loss: 1.2879
# Epoch 15: val_accuracy improved from 0.60917 to 0.62091, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 15: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.5805 - loss: 1.2816 - val_accuracy: 0.6209 - val_loss: 1.2057 - learning_rate: 5.0000e-04
# Epoch 16/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5796 - loss: 1.2727
# Epoch 16: val_accuracy did not improve from 0.62091
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.5829 - loss: 1.2695 - val_accuracy: 0.5868 - val_loss: 1.2738 - learning_rate: 5.0000e-04
# Epoch 17/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5881 - loss: 1.2604
# Epoch 17: val_accuracy did not improve from 0.62091
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.5923 - loss: 1.2513 - val_accuracy: 0.6053 - val_loss: 1.2394 - learning_rate: 5.0000e-04
# Epoch 18/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.5890 - loss: 1.2545
# Epoch 18: val_accuracy did not improve from 0.62091
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.5950 - loss: 1.2519 - val_accuracy: 0.5871 - val_loss: 1.2918 - learning_rate: 5.0000e-04
# Epoch 19/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6126 - loss: 1.1997
# Epoch 19: val_accuracy improved from 0.62091 to 0.64260, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 19: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6186 - loss: 1.1827 - val_accuracy: 0.6426 - val_loss: 1.1424 - learning_rate: 1.5000e-04
# Epoch 20/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6192 - loss: 1.1781
# Epoch 20: val_accuracy did not improve from 0.64260
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6233 - loss: 1.1707 - val_accuracy: 0.6422 - val_loss: 1.1348 - learning_rate: 1.5000e-04
# Epoch 21/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6167 - loss: 1.1663
# Epoch 21: val_accuracy did not improve from 0.64260
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6224 - loss: 1.1624 - val_accuracy: 0.6387 - val_loss: 1.1477 - learning_rate: 1.5000e-04
# Epoch 22/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6247 - loss: 1.1577
# Epoch 22: val_accuracy improved from 0.64260 to 0.64723, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 22: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6273 - loss: 1.1557 - val_accuracy: 0.6472 - val_loss: 1.1236 - learning_rate: 1.5000e-04
# Epoch 23/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6235 - loss: 1.1537
# Epoch 23: val_accuracy did not improve from 0.64723
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6271 - loss: 1.1463 - val_accuracy: 0.6408 - val_loss: 1.1230 - learning_rate: 1.5000e-04
# Epoch 24/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6279 - loss: 1.1581
# Epoch 24: val_accuracy did not improve from 0.64723
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6315 - loss: 1.1470 - val_accuracy: 0.6422 - val_loss: 1.1342 - learning_rate: 1.5000e-04
# Epoch 25/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6286 - loss: 1.1395
# Epoch 25: val_accuracy did not improve from 0.64723
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6335 - loss: 1.1344 - val_accuracy: 0.6469 - val_loss: 1.1280 - learning_rate: 1.5000e-04
# Epoch 26/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6314 - loss: 1.1348
# Epoch 26: val_accuracy did not improve from 0.64723
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6298 - loss: 1.1355 - val_accuracy: 0.6472 - val_loss: 1.1119 - learning_rate: 1.5000e-04
# Epoch 27/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6330 - loss: 1.1341
# Epoch 27: val_accuracy did not improve from 0.64723
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6331 - loss: 1.1312 - val_accuracy: 0.6426 - val_loss: 1.1141 - learning_rate: 1.5000e-04
# Epoch 28/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6336 - loss: 1.1355
# Epoch 28: val_accuracy improved from 0.64723 to 0.65114, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 28: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6332 - loss: 1.1313 - val_accuracy: 0.6511 - val_loss: 1.0925 - learning_rate: 1.5000e-04
# Epoch 29/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6347 - loss: 1.1261
# Epoch 29: val_accuracy did not improve from 0.65114
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6329 - loss: 1.1256 - val_accuracy: 0.6469 - val_loss: 1.1137 - learning_rate: 1.5000e-04
# Epoch 30/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6383 - loss: 1.1191
# Epoch 30: val_accuracy did not improve from 0.65114
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 65ms/step - accuracy: 0.6391 - loss: 1.1162 - val_accuracy: 0.6451 - val_loss: 1.1175 - learning_rate: 1.5000e-04
# Epoch 31/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6400 - loss: 1.1150
# Epoch 31: val_accuracy improved from 0.65114 to 0.65612, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 31: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 31: ReduceLROnPlateau reducing learning rate to 4.500000213738531e-05.
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6390 - loss: 1.1140 - val_accuracy: 0.6561 - val_loss: 1.0952 - learning_rate: 1.5000e-04
# Epoch 32/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6477 - loss: 1.0952
# Epoch 32: val_accuracy did not improve from 0.65612
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6480 - loss: 1.0887 - val_accuracy: 0.6561 - val_loss: 1.0759 - learning_rate: 4.5000e-05
# Epoch 33/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6489 - loss: 1.0927
# Epoch 33: val_accuracy improved from 0.65612 to 0.66003, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 33: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6504 - loss: 1.0895 - val_accuracy: 0.6600 - val_loss: 1.0740 - learning_rate: 4.5000e-05
# Epoch 34/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6498 - loss: 1.0853
# Epoch 34: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6502 - loss: 1.0845 - val_accuracy: 0.6547 - val_loss: 1.0765 - learning_rate: 4.5000e-05
# Epoch 35/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6434 - loss: 1.0877
# Epoch 35: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6461 - loss: 1.0849 - val_accuracy: 0.6554 - val_loss: 1.0721 - learning_rate: 4.5000e-05
# Epoch 36/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6528 - loss: 1.0827
# Epoch 36: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6526 - loss: 1.0807 - val_accuracy: 0.6583 - val_loss: 1.0761 - learning_rate: 4.5000e-05
# Epoch 37/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6485 - loss: 1.0723
# Epoch 37: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6509 - loss: 1.0733 - val_accuracy: 0.6543 - val_loss: 1.0743 - learning_rate: 4.5000e-05
# Epoch 38/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6553 - loss: 1.0779
# Epoch 38: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6553 - loss: 1.0741 - val_accuracy: 0.6590 - val_loss: 1.0637 - learning_rate: 4.5000e-05
# Epoch 39/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6545 - loss: 1.0675
# Epoch 39: val_accuracy did not improve from 0.66003
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6544 - loss: 1.0694 - val_accuracy: 0.6600 - val_loss: 1.0695 - learning_rate: 4.5000e-05
# Epoch 40/40
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.6553 - loss: 1.0798
# Epoch 40: val_accuracy improved from 0.66003 to 0.66181, saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
#
# Epoch 40: finished saving model to /kaggle/working/07_cnn_regularizada_arrays.keras
# 498/498 ━━━━━━━━━━━━━━━━━━━━ 33s 66ms/step - accuracy: 0.6546 - loss: 1.0746 - val_accuracy: 0.6618 - val_loss: 1.0639 - learning_rate: 4.5000e-05
# Restoring model weights from the end of the best epoch: 40.
# Best validation model: epoch 40 - val_accuracy 0.6618065237998962
# Tiempo entrenamiento: 1333.12 s

# %% [markdown]
# ## Resultados

# %% [markdown]
# ### Graficas

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='valid')
plt.title('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='valid')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Predicciones de validacion

# %%
model.load_weights(MODEL_PATH)

valid_loss, valid_accuracy = model.evaluate(X_valid, y_valid, batch_size=BATCH_SIZE, verbose=1)
print('Validation loss:', valid_loss)
print('Validation accuracy:', valid_accuracy)

probs = model.predict(X_valid, batch_size=BATCH_SIZE, verbose=1)
y_pred_idx = np.argmax(probs, axis=1)
y_true_idx = y_valid_idx
# Out:
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.6618 - loss: 1.0639
# Validation loss: 1.0638848543167114
# Validation accuracy: 0.6618065237998962
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step

# %% [markdown]
# ### Matriz de confusion

# %%
cm = confusion_matrix(y_true_idx, y_pred_idx, labels=list(range(num_classes)))

def draw_confusion_matrix_percent(cm, labels):
    cm_norm = cm.astype(float) / np.maximum(cm.sum(axis=1, keepdims=True), np.finfo(np.float64).eps)

    fig, ax = plt.subplots(figsize=(14, 12))
    im = ax.imshow(cm_norm, interpolation='nearest', cmap=plt.colormaps['Blues'], vmin=0.0, vmax=max(0.01, cm_norm.max()))
    fig.colorbar(im, ax=ax)

    ax.set(
        xticks=np.arange(len(labels)),
        yticks=np.arange(len(labels)),
        xticklabels=labels,
        yticklabels=labels,
        ylabel='Annotation',
        xlabel='Prediction',
    )
    plt.setp(ax.get_xticklabels(), rotation=45, ha='right', rotation_mode='anchor')

    threshold = cm_norm.max() / 2.0
    for i in range(cm_norm.shape[0]):
        for j in range(cm_norm.shape[1]):
            value = cm_norm[i, j]
            ax.text(
                j,
                i,
                f'{value:.2f}',
                ha='center',
                va='center',
                color='white' if value > threshold else 'black',
                fontsize=9,
            )

    fig.tight_layout()
    plt.show()
    return cm_norm

cm_norm = draw_confusion_matrix_percent(cm, category_names)

# %% [markdown]
# ### Metricas

# %%
print(classification_report(y_true_idx, y_pred_idx, target_names=category_names, digits=4))
# Out:
#                     precision    recall  f1-score   support
#
#        Cargo plane     0.9551    0.8947    0.9239        95
#          Small car     0.6633    0.9319    0.7750       499
#                Bus     0.4949    0.5472    0.5197       265
#              Truck     0.3690    0.2078    0.2659       332
#          Motorboat     0.7929    0.6937    0.7400       160
#     Fishing vessel     0.8081    0.7547    0.7805       106
#         Dump truck     0.5871    0.4919    0.5353       185
#          Excavator     0.6127    0.7373    0.6692       118
#           Building     0.7496    0.8219    0.7841       539
#            Helipad     0.5000    0.0588    0.1053        17
#       Storage tank     0.7459    0.4136    0.5322       220
# Shipping container     0.6437    0.6943    0.6681       229
#              Pylon     0.7727    0.7234    0.7473        47
#
#           accuracy                         0.6618      2812
#          macro avg     0.6688    0.6132    0.6190      2812
#       weighted avg     0.6505    0.6618    0.6434      2812

# %% [markdown]
# ## Codabench

# %% [markdown]
# ### Generacion del submission

# %%
CODABENCH_START = time.perf_counter()

def load_test_image(filename):
    return np.array(Image.open(DATA_ROOT / filename).convert('RGB'))

test_files = sorted(TEST_DIR.rglob('*.tif'))
print('Number of testing images:', len(test_files))
assert len(test_files) > 0, 'No se encontraron imagenes .tif en TEST_DIR.'

model.load_weights(MODEL_PATH)
predictions_data = {'images': {}, 'annotations': {}}
batch_size = 64

for start in range(0, len(test_files), batch_size):
    batch_paths = test_files[start:start + batch_size]
    json_filenames = [path.relative_to(TEST_DIR).as_posix() for path in batch_paths]
    load_filenames = [path.relative_to(DATA_ROOT).as_posix() for path in batch_paths]

    images = np.stack([load_test_image(filename) for filename in load_filenames]).astype(np.uint8)
    probs = model.predict(images, batch_size=batch_size, verbose=0)
    pred_idx = np.argmax(probs, axis=1)
    pred_scores = np.max(probs, axis=1)

    for offset, (path, json_filename, cls_idx, score) in enumerate(zip(batch_paths, json_filenames, pred_idx, pred_scores)):
        idx = start + offset
        predictions_data['images'][idx] = {
            'image_id': path.name,
            'filename': json_filename,
            'width': 224,
            'height': 224,
        }
        predictions_data['annotations'][idx] = {
            'image_id': path.name,
            'category_id': category_names[int(cls_idx)],
            'score': float(score),
            'bbox': [0, 0, 224, 224],
        }

    print(f'Procesadas {min(start + batch_size, len(test_files))}/{len(test_files)}')

assert len(predictions_data['images']) == len(test_files)
assert len(predictions_data['annotations']) == len(test_files)

prediction_path = WORKDIR / 'prediction_07.json'
submission_path = WORKDIR / 'submission_07.zip'

with open(prediction_path, 'w', encoding='utf-8') as outfile:
    json.dump(predictions_data, outfile)

with zipfile.ZipFile(submission_path, 'w', compression=zipfile.ZIP_DEFLATED) as zf:
    zf.write(prediction_path, arcname='prediction.json')

CODABENCH_TIME = time.perf_counter() - CODABENCH_START

print('Archivos generados:')
print(prediction_path, '-', prediction_path.stat().st_size, 'bytes')
print(submission_path, '-', submission_path.stat().st_size, 'bytes')
print(f'Tiempo Codabench: {CODABENCH_TIME:.2f} s')

from IPython.display import FileLink, display
display(FileLink(str(submission_path)))
# Out:
# Number of testing images: 2365
# Procesadas 64/2365
# Procesadas 128/2365
# Procesadas 192/2365
# Procesadas 256/2365
# Procesadas 320/2365
# Procesadas 384/2365
# Procesadas 448/2365
# Procesadas 512/2365
# Procesadas 576/2365
# Procesadas 640/2365
# Procesadas 704/2365
# Procesadas 768/2365
# Procesadas 832/2365
# Procesadas 896/2365
# Procesadas 960/2365
# Procesadas 1024/2365
# Procesadas 1088/2365
# Procesadas 1152/2365
# Procesadas 1216/2365
# Procesadas 1280/2365
# Procesadas 1344/2365
# Procesadas 1408/2365
# Procesadas 1472/2365
# Procesadas 1536/2365
# Procesadas 1600/2365
# Procesadas 1664/2365
# Procesadas 1728/2365
# Procesadas 1792/2365
# Procesadas 1856/2365
# Procesadas 1920/2365
# Procesadas 1984/2365
# Procesadas 2048/2365
# Procesadas 2112/2365
# Procesadas 2176/2365
# Procesadas 2240/2365
# Procesadas 2304/2365
# Procesadas 2365/2365
# Archivos generados:
# /kaggle/working/prediction_07.json - 729451 bytes
# /kaggle/working/submission_07.zip - 165132 bytes
# Tiempo Codabench: 28.77 s
# /kaggle/working/submission_07.zip

# %% [markdown]
# ### Resumen de tiempos

# %%
TOTAL_TIME = time.perf_counter() - RUN_START
print('Resumen de tiempos')
if 'DATA_LOAD_TIME' in globals():
    print(f'- Carga/preparacion de datos: {DATA_LOAD_TIME:.2f} s')
if 'TRAIN_TIME' in globals():
    print(f'- Entrenamiento: {TRAIN_TIME:.2f} s')
if 'CODABENCH_TIME' in globals():
    print(f'- Codabench: {CODABENCH_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME:.2f} s')
print(f'- Tiempo total Run All: {TOTAL_TIME / 60:.2f} min')
# Out:
# Resumen de tiempos
# - Carga/preparacion de datos: 20.91 s
# - Entrenamiento: 1333.12 s
# - Codabench: 28.77 s
# - Tiempo total Run All: 1408.76 s
# - Tiempo total Run All: 23.48 min
